# %% [markdown]
# ### word2vec기반 연관어 분석
# - 단순히 출현횟수만을 고려하는 것이 아닌 단어 위치, 순서도 고려하는 방법
#     1. CBOW: 주변 단어로 중심 단어를 예측하는 방법
#     2. Skip-gram: 중심 단어로 주변 단어를 예측하는 방법(최근 더 많이 사용)

# %%
#긍정리뷰
import glob
pos_review = (glob.glob('c:/data/imdb/train/pos/*.txt'))
lines_pos = []
for i in pos_review:
    try:
        f = open(i, 'r')
        temp = f.readlines()[0]
        lines_pos.append(temp)
        f.close()
    except:
        continue
len(lines_pos)
# Out:
# 12490

# %%
#전처리
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
tokenizer = RegexpTokenizer('[\w]+') # 알파벳, 숫자, -
stop_words = stopwords.words('english')
text = []
for line in lines_pos:
    words = line.lower()
    tokens = tokenizer.tokenize(words)
    # 불용어('br'추가) 제거
    stopped_tokens = [i for i in list(set(tokens)) if i not in stop_words + ['br']]
    # 글자수가 1인 단어 제외
    stopped_tokens2 = [i for i in stopped_tokens if len(i) > 1]
    text.append(stopped_tokens2)

# %%
#word2vec모형 생성
from gensim.models.word2vec import Word2Vec
# sg=1: skip-gram 적용
# window=2: 중심단어로부터 좌우 2개의 단어까지 학습
# min_count=3: 최소 3회 이상 출현한 단어들을 대상으로 학습
model = Word2Vec(text, vector_size=100, sg=1, window=2, min_count=3)

# %%
#두 단어의 유사도 계산
model.wv.similarity('film', 'movie')
# Out:
# 0.3493027

# %%
#good과 가장 유사한 단어 5개
model.wv.most_similar('good', topn=5)
# Out:
# [('course', 0.8597866892814636),
#  ('moment', 0.8458071947097778),
#  ('unique', 0.8370854258537292),
#  ('getting', 0.8344937562942505),
#  ('language', 0.8338459730148315)]

# %%
#모델에 저장된 단어의 개수
len(model.wv.index_to_key)
# Out:
# 26355

# %%
#모델에 저장된 단어 텍스트
model.wv.index_to_key
# Out:
# ['one',
#  'film',
#  'movie',
#  'like',
#  'good',
#  'time',
#  'well',
#  'great',
#  'see',
#  'story',
#  'also',
#  'would',
#  'really',
#  'even',
#  'much',
#  'first',
#  'get',
#  'best',
#  'way',
#  'people',
#  'made',
#  'love',
#  'many',
#  'life',
#  'seen',
#  'watch',
#  'think',
#  'two',
#  'make',
#  'still',
#  'never',
#  'characters',
#  'films',
#  'movies',
#  'could',
#  'little',
#  'character',
#  'man',
#  'know',
#  'ever',
#  'end',
#  'years',
#  'acting',
#  'back',
#  'go',
#  'makes',
#  'real',
#  'say',
#  'better',
#  'though',
#  'plot',
#  'scene',
#  'work',
#  'scenes',
#  'find',
#  'new',
#  'cast',
#  'world',
#  'old',
#  'show',
#  'something',
#  'another',
#  'always',
#  '10',
#  'lot',
#  'quite',
#  'young',
#  'director',
#  'actors',
#  'watching',
#  'every',
#  'part',
#  'look',
#  'times',
#  'may',
#  'us',
#  'things',
#  'funny',
#  'bad',
#  'performance',
#  'role',
#  'going',
#  'must',
#  'however',
#  'take',
#  'actually',
#  'saw',
#  'bit',
#  'without',
#  'long',
#  'excellent',
#  'thing',
#  'big',
#  'right',
#  'fact',
#  'around',
#  'especially',
#  'come',
#  'give',
#  'thought',
#  'got',
#  'family',
#  'done',
#  'feel',
#  'almost',
#  'want',
#  'fun',
#  'beautiful',
#  'since',
#  'music',
#  'seems',
#  'last',
#  'although',
#  'comedy',
#  'day',
#  'gets',
#  'true',
#  'yet',
#  'interesting',
#  'played',
#  'pretty',
#  'different',
#  'job',
#  'enough',
#  'action',
#  'course',
#  'probably',
#  'shows',
#  'far',
#  'wonderful',
#  'plays',
#  'hard',
#  'away',
#  'point',
#  'worth',
#  'whole',
#  'found',
#  'together',
#  'set',
#  'series',
#  'comes',
#  'sure',
#  'screen',
#  'making',
#  'nothing',
#  'takes',
#  'performances',
#  'rather',
#  'place',
#  'later',
#  'anyone',
#  'woman',
#  'dvd',
#  'goes',
#  'everyone',
#  'original',
#  'perfect',
#  'year',
#  'girl',
#  'kind',
#  'tv',
#  'might',
#  'enjoy',
#  'put',
#  'least',
#  'everything',
#  'classic',
#  'seeing',
#  'ending',
#  'actor',
#  'recommend',
#  'john',
#  'watched',
#  'play',
#  'anything',
#  'believe',
#  'three',
#  'looking',
#  'american',
#  'loved',
#  'top',
#  'nice',
#  'gives',
#  'wife',
#  'definitely',
#  'high',
#  'main',
#  'mind',
#  'seem',
#  'along',
#  'truly',
#  'father',
#  'night',
#  'sense',
#  'amazing',
#  'second',
#  'small',
#  'fan',
#  'trying',
#  'special',
#  'audience',
#  'full',
#  'said',
#  'others',
#  'hollywood',
#  'guy',
#  'help',
#  'star',
#  'favorite',
#  'often',
#  'home',
#  'let',
#  'left',
#  'script',
#  'remember',
#  'came',
#  'less',
#  'friends',
#  'maybe',
#  'short',
#  'live',
#  'become',
#  'highly',
#  'heart',
#  'men',
#  'enjoyed',
#  'used',
#  'shot',
#  'moments',
#  'entertaining',
#  'early',
#  'brilliant',
#  'liked',
#  'human',
#  'horror',
#  'today',
#  'stars',
#  'keep',
#  'lives',
#  'death',
#  'use',
#  'given',
#  'overall',
#  'perhaps',
#  'style',
#  'need',
#  'next',
#  'book',
#  'looks',
#  'else',
#  'line',
#  'playing',
#  'black',
#  'works',
#  'someone',
#  'throughout',
#  'fine',
#  'drama',
#  'certainly',
#  'finally',
#  'version',
#  'read',
#  'try',
#  'effects',
#  'simply',
#  'rest',
#  'written',
#  'based',
#  'reason',
#  'understand',
#  'minutes',
#  'house',
#  'face',
#  'cinema',
#  'war',
#  'couple',
#  'several',
#  'picture',
#  'hope',
#  'beginning',
#  'friend',
#  'lost',
#  'tell',
#  'start',
#  'strong',
#  'dark',
#  'fans',
#  'history',
#  'late',
#  'boy',
#  'able',
#  'idea',
#  'despite',
#  'completely',
#  'getting',
#  'instead',
#  'becomes',
#  'final',
#  'production',
#  'roles',
#  'person',
#  'yes',
#  'dead',
#  'sometimes',
#  'past',
#  'either',
#  'humor',
#  'days',
#  'side',
#  'wrong',
#  'turns',
#  'half',
#  'kids',
#  'mother',
#  'women',
#  'case',
#  'soon',
#  'simple',
#  'camera',
#  'viewer',
#  'white',
#  'children',
#  'close',
#  'name',
#  'absolutely',
#  'direction',
#  'genre',
#  'title',
#  'money',
#  'went',
#  'felt',
#  'directed',
#  'age',
#  'head',
#  'piece',
#  'wants',
#  'parts',
#  'turn',
#  'experience',
#  'eyes',
#  'called',
#  'fantastic',
#  'including',
#  'behind',
#  'example',
#  'ago',
#  'known',
#  'school',
#  'city',
#  'child',
#  'score',
#  'already',
#  'lead',
#  'lines',
#  'art',
#  'chance',
#  'moving',
#  'video',
#  'episode',
#  'sort',
#  'stories',
#  'supporting',
#  'cinematography',
#  'son',
#  'matter',
#  'feeling',
#  'hilarious',
#  'living',
#  'relationship',
#  'told',
#  'quality',
#  'mr',
#  'actress',
#  'enjoyable',
#  'light',
#  'moment',
#  'expect',
#  'happy',
#  'laugh',
#  'superb',
#  'released',
#  'dialogue',
#  'gave',
#  'entire',
#  'coming',
#  'town',
#  'hit',
#  'particularly',
#  'low',
#  'type',
#  'somewhat',
#  'took',
#  'hand',
#  'budget',
#  'michael',
#  'view',
#  'finds',
#  'change',
#  'heard',
#  'important',
#  'leave',
#  'evil',
#  'james',
#  'sound',
#  'mean',
#  'usual',
#  'whose',
#  'run',
#  'wanted',
#  'easy',
#  'opinion',
#  'shown',
#  'future',
#  'modern',
#  'reality',
#  'self',
#  'etc',
#  'murder',
#  'tells',
#  'alone',
#  'career',
#  'care',
#  'totally',
#  'greatest',
#  'sex',
#  'writing',
#  'starts',
#  'taken',
#  'robert',
#  'involved',
#  'voice',
#  'attention',
#  'oscar',
#  'surprised',
#  'writer',
#  'country',
#  'wish',
#  'taking',
#  'stuff',
#  'fight',
#  'events',
#  'similar',
#  'number',
#  'romantic',
#  'brother',
#  'problem',
#  'across',
#  'miss',
#  'ways',
#  'act',
#  'perfectly',
#  'serious',
#  'realistic',
#  'seemed',
#  'violence',
#  'ones',
#  'extremely',
#  'david',
#  'anyway',
#  'due',
#  'says',
#  'among',
#  'tale',
#  'husband',
#  'order',
#  'easily',
#  'tries',
#  'song',
#  'sad',
#  'knows',
#  'exactly',
#  'cannot',
#  'slow',
#  'happened',
#  'brought',
#  'stop',
#  'entertainment',
#  'thinking',
#  'begins',
#  'interest',
#  'daughter',
#  'english',
#  'famous',
#  'power',
#  'viewing',
#  'memorable',
#  'happen',
#  'unique',
#  'opening',
#  'atmosphere',
#  'sets',
#  'believable',
#  'working',
#  'mostly',
#  'knew',
#  'bring',
#  'guys',
#  'ends',
#  'episodes',
#  'level',
#  'upon',
#  'television',
#  'musical',
#  'powerful',
#  'middle',
#  'usually',
#  'kid',
#  'strange',
#  'paul',
#  'masterpiece',
#  'within',
#  'thriller',
#  'comic',
#  'beauty',
#  'form',
#  'eye',
#  'soundtrack',
#  'possible',
#  'meets',
#  'certain',
#  'happens',
#  'obviously',
#  'whether',
#  'cool',
#  'particular',
#  'kill',
#  'follow',
#  'songs',
#  'stand',
#  'york',
#  'car',
#  'release',
#  'theme',
#  'hero',
#  'period',
#  'brings',
#  'words',
#  'problems',
#  'group',
#  'class',
#  'police',
#  'needs',
#  'showing',
#  'huge',
#  'flick',
#  'viewers',
#  'emotional',
#  'typical',
#  'unfortunately',
#  'deal',
#  'richard',
#  'guess',
#  'room',
#  'british',
#  'message',
#  'leads',
#  'game',
#  'major',
#  'giving',
#  'deep',
#  'talent',
#  'documentary',
#  'elements',
#  'four',
#  'turned',
#  'local',
#  'except',
#  'nearly',
#  'near',
#  'started',
#  'feature',
#  'surprise',
#  'killed',
#  'nature',
#  'killer',
#  'sweet',
#  'recommended',
#  'obvious',
#  'girls',
#  'indeed',
#  'sequence',
#  'personal',
#  'novel',
#  'george',
#  'poor',
#  'unlike',
#  'became',
#  'running',
#  'fast',
#  'crime',
#  'romance',
#  'incredible',
#  'mystery',
#  'jack',
#  'complete',
#  'buy',
#  'wonder',
#  'named',
#  'note',
#  'fall',
#  'parents',
#  'talking',
#  'keeps',
#  'eventually',
#  'clearly',
#  'america',
#  'hours',
#  'society',
#  'clear',
#  'hour',
#  'filmed',
#  'feels',
#  'french',
#  'beyond',
#  'team',
#  'add',
#  'means',
#  'sister',
#  'beautifully',
#  'gone',
#  'older',
#  'difficult',
#  'non',
#  'lots',
#  'meet',
#  'learn',
#  'leaves',
#  'earlier',
#  'body',
#  'word',
#  'situation',
#  'appears',
#  'touching',
#  'doubt',
#  'recently',
#  'single',
#  'female',
#  'era',
#  'comments',
#  'hear',
#  'present',
#  'animation',
#  'falls',
#  'check',
#  'forget',
#  'blood',
#  'truth',
#  'portrayal',
#  'five',
#  'setting',
#  'king',
#  'solid',
#  'using',
#  'dramatic',
#  'rating',
#  'peter',
#  'plenty',
#  'success',
#  'call',
#  'subject',
#  'cut',
#  'lack',
#  'points',
#  'figure',
#  'interested',
#  'oh',
#  'dream',
#  'general',
#  'move',
#  'third',
#  'rock',
#  'disappointed',
#  'business',
#  'ten',
#  'leading',
#  'william',
#  'shots',
#  'deserves',
#  'suspense',
#  'stage',
#  'talk',
#  'sees',
#  'sequences',
#  'acted',
#  'terrific',
#  'outstanding',
#  'lady',
#  'hell',
#  'portrayed',
#  'none',
#  'features',
#  'straight',
#  'return',
#  'pace',
#  'rare',
#  'appreciate',
#  'god',
#  'fantasy',
#  'please',
#  'street',
#  'towards',
#  'earth',
#  'charming',
#  'various',
#  'familiar',
#  'looked',
#  'married',
#  'actual',
#  'rate',
#  'screenplay',
#  'moves',
#  'subtle',
#  'mention',
#  'basically',
#  'popular',
#  'awesome',
#  'red',
#  'caught',
#  'open',
#  'realize',
#  'imagine',
#  'effective',
#  'intelligent',
#  'background',
#  'saying',
#  'kept',
#  'boring',
#  'manages',
#  'scary',
#  'language',
#  'storyline',
#  'hate',
#  'effect',
#  'decent',
#  'impressive',
#  'wait',
#  'material',
#  'stunning',
#  'social',
#  'telling',
#  'theater',
#  'rich',
#  'adventure',
#  'uses',
#  'reading',
#  'pure',
#  'seriously',
#  'directors',
#  'supposed',
#  'tom',
#  'expected',
#  'dance',
#  'mark',
#  'stay',
#  'filled',
#  'natural',
#  'season',
#  'surprisingly',
#  'somehow',
#  'sexual',
#  'follows',
#  'successful',
#  'jokes',
#  'century',
#  'previous',
#  'touch',
#  'inside',
#  'question',
#  'attempt',
#  'quickly',
#  'hands',
#  'following',
#  'air',
#  'apart',
#  'created',
#  'average',
#  'die',
#  'battle',
#  'admit',
#  'thanks',
#  'missed',
#  'create',
#  'reasons',
#  'crazy',
#  'cold',
#  'complex',
#  'recent',
#  'exciting',
#  'de',
#  'free',
#  'brothers',
#  'gem',
#  'knowing',
#  'visual',
#  'begin',
#  'clever',
#  'casting',
#  'slightly',
#  'ok',
#  'minute',
#  'reviews',
#  'baby',
#  'worked',
#  'adult',
#  'male',
#  'wonderfully',
#  'outside',
#  'younger',
#  'agree',
#  'emotions',
#  'needed',
#  'starring',
#  'front',
#  'fairly',
#  'talented',
#  'boys',
#  'cute',
#  'hot',
#  'review',
#  '20',
#  'decided',
#  'edge',
#  'members',
#  'lovely',
#  'hold',
#  'comment',
#  'genius',
#  'political',
#  'large',
#  'forward',
#  'possibly',
#  'office',
#  'fascinating',
#  'spirit',
#  'co',
#  'journey',
#  'space',
#  'copy',
#  'plus',
#  'break',
#  'convincing',
#  'forced',
#  'escape',
#  'secret',
#  'appear',
#  'mentioned',
#  'magic',
#  'result',
#  'apparently',
#  'laughs',
#  'silly',
#  'focus',
#  'whatever',
#  'choice',
#  'images',
#  'editing',
#  'compared',
#  'themes',
#  'weird',
#  'directing',
#  'odd',
#  'produced',
#  'twists',
#  'glad',
#  'chemistry',
#  'dr',
#  'former',
#  'creepy',
#  'missing',
#  'credits',
#  'decides',
#  'singing',
#  'died',
#  'ultimately',
#  'save',
#  'catch',
#  'helps',
#  'state',
#  'public',
#  'feelings',
#  'shame',
#  'expecting',
#  'otherwise',
#  'consider',
#  'honest',
#  'master',
#  'fighting',
#  'meant',
#  'sit',
#  'compelling',
#  'fully',
#  'tough',
#  'respect',
#  'ask',
#  'audiences',
#  'fear',
#  'lee',
#  'gorgeous',
#  'sounds',
#  'waiting',
#  'award',
#  'equally',
#  'depth',
#  'sequel',
#  'ride',
#  'animated',
#  'violent',
#  'innocent',
#  'fresh',
#  'personally',
#  'tone',
#  'disney',
#  'girlfriend',
#  'considered',
#  'bill',
#  'runs',
#  'showed',
#  'box',
#  'culture',
#  'force',
#  'frank',
#  'provides',
#  'remains',
#  'win',
#  'studio',
#  'pictures',
#  'trip',
#  'available',
#  'law',
#  'common',
#  'stands',
#  'normal',
#  'fi',
#  'key',
#  'party',
#  'changed',
#  'tragic',
#  'credit',
#  'sci',
#  'entirely',
#  'company',
#  'considering',
#  'loves',
#  'situations',
#  'development',
#  'charm',
#  'amusing',
#  'western',
#  'stupid',
#  'joe',
#  'cry',
#  'japanese',
#  'tension',
#  'dialog',
#  'fit',
#  'effort',
#  'incredibly',
#  'mary',
#  'post',
#  '30',
#  'impressed',
#  'tried',
#  'trouble',
#  'list',
#  'leaving',
#  'twist',
#  'rent',
#  'drawn',
#  'slowly',
#  'crew',
#  'funniest',
#  'immediately',
#  'laughing',
#  'heavy',
#  'killing',
#  'terms',
#  'dog',
#  'sent',
#  'dancing',
#  'minor',
#  'meaning',
#  'fire',
#  'control',
#  'longer',
#  'worst',
#  'conclusion',
#  'villain',
#  'winning',
#  'fiction',
#  'imdb',
#  'amount',
#  'photography',
#  'dreams',
#  'questions',
#  'contains',
#  'thank',
#  'pay',
#  'date',
#  'intense',
#  'humour',
#  ...]

# %%
#단어에 해당하는 벡터값
model.wv.vectors[0]
# Out:
# array([-8.09380412e-01,  3.99832159e-01,  8.46634388e-01,  6.12508692e-02,
#        -8.82748723e-01, -2.96960652e-01,  1.02314377e+00,  1.91467345e-01,
#        -4.86356795e-01, -5.04792249e-03,  1.74993858e-01, -2.99924821e-01,
#         1.60585120e-01, -1.01314969e-01,  3.81359935e-01, -3.08519155e-01,
#        -2.07324654e-01, -5.26919425e-01, -4.55963403e-01, -7.09635675e-01,
#         3.13847542e-01,  9.99324501e-01,  3.65712136e-01, -1.14540190e-01,
#         2.23823547e-01, -2.18353823e-01,  9.39392298e-02, -3.14762563e-01,
#        -5.37570715e-01, -3.88826758e-01, -6.95863485e-01, -4.44568358e-02,
#         2.29748115e-01, -8.50549638e-01, -1.07110608e+00,  3.94998819e-01,
#         5.80289304e-01, -7.89921224e-01,  2.47520372e-01, -6.00702345e-01,
#        -4.47840005e-01,  1.34651625e+00, -6.34443223e-01, -4.47588056e-01,
#         7.36200571e-01, -2.98571110e-01, -7.77476072e-01,  4.41440523e-01,
#         3.43774348e-01,  3.55526000e-01, -3.02182049e-01, -2.28794679e-01,
#        -6.50576830e-01, -1.03357024e-01,  3.77604425e-01,  2.44704157e-01,
#         7.71224797e-01, -2.74047315e-01, -3.51262540e-01,  5.65678000e-01,
#         2.47090697e-01,  2.37420067e-01, -5.05015612e-01, -6.59495473e-01,
#         3.90379280e-01,  4.78272498e-01, -7.89677382e-01,  6.99031830e-01,
#        -7.55518675e-01,  2.28687569e-01,  1.89968869e-01,  1.69077694e+00,
#         5.41557550e-01, -7.33738959e-01,  6.45521939e-01, -3.43015827e-02,
#         1.15170807e-01, -4.78359163e-01, -5.84927201e-01, -2.37108208e-02,
#         2.79942572e-01,  1.07306086e-01,  4.39557791e-01,  4.11727309e-01,
#        -1.28063157e-01, -3.81850988e-01,  8.51390243e-01, -2.38720536e-01,
#         2.28504092e-01,  7.49403477e-01,  3.82342011e-01,  4.33097869e-01,
#         5.83009385e-02,  3.18399668e-02,  9.24832046e-01,  1.17701256e+00,
#        -1.27125040e-01, -9.71628964e-01,  3.20563704e-01, -1.06993678e-03],
#       dtype=float32)
