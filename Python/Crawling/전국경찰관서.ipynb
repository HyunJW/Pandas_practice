# %% [markdown]
# # 경찰청 주소를 지도에 나타내기

# %%
from bs4 import BeautifulSoup
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import folium
from urllib.parse import quote
import json
import requests

# %%
# kakao key 가져오기
with open(r'C:\workspace\api_key\kakao_key.txt') as file:
    kakao_key = file.read()

# %%
url = 'https://www.police.go.kr/user/bbs/BD_selectBbsList.do?q_bbsCode=1038&q_tab=1'
driver = webdriver.Chrome('chromedriver.exe')
driver.get(url)

# %% [markdown]
# ## 1. 서울지역 경찰서로 정보확인

# %%
# 전국경찰관서 중 서울 클릭
driver.find_element(By.ID, 'tab_1').click()
time.sleep(3)

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
lis = soup.select('tbody > tr')

# %%
# 서울 지역의 관서 개수 확인
len(lis)
# Out:
# 32

# %%
# 가장 마지막에 위치한 관서로 정보 확인 - 서울혜화경찰서
li = lis[-1]

# %%
li
# Out:
# <tr>
# <td class="show-col">서울혜화경찰서</td>
# <td class="show-col">서울시 종로구 창경궁로 112-16 </td>
# <td class="show-col">
# <a href="https://www.smpa.go.kr/hh/" target="_blank" title="새창열림">https://www.smpa.go.kr/hh/</a>
# </td>
# </tr>

# %%
# 경찰서 이름
title = li.select('.show-col')[0].text
title
# Out:
# '서울혜화경찰서'

# %%
# 경찰서 주소
addr = li.select('.show-col')[1].text
addr
# Out:
# '서울시 종로구 창경궁로 112-16 '

# %%
# 경찰서 홈페이지 주소
href = li.select('.show-col')[2].text.replace('\n','')
href
# Out:
# 'https://www.smpa.go.kr/hh/'

# %%
# kakao key를 이용해서 주소로 위도, 경도 구하기
local_url = 'https://dapi.kakao.com/v2/local/search/address.json'
headers = {"Authorization": "KakaoAK " + kakao_key}
url = f'{local_url}?query={quote(addr)}'
result = requests.get(url, headers = headers).json()['documents']

float(result[0]['y']), float(result[0]['x'])
# Out:
# (37.5717676404547, 126.999273268519)

# %%
# 서울지역 관서들 가져오기
lines = []

for li in lis:
    title = li.select('.show-col')[0].text
    addr = li.select('.show-col')[1].text
    href = li.select('.show-col')[2].text

    lines.append([title, addr, href])

# %%
df = pd.DataFrame(lines, columns=['관서명', '주소', '홈페이지'])
df
# Out:
#          관서명                    주소                               홈페이지
# 0   서울특별시경찰청     서울시 종로구 사직로8길 31         \nhttps://www.smpa.go.kr/\n
# 1    서울강남경찰서  서울시 강남구 테헤란로 114길 11     \nhttps://www.smpa.go.kr/gn/\n
# 2    서울강동경찰서        서울시 강동구 성내로 57     \nhttps://www.smpa.go.kr/gd/\n
# 3    서울강북경찰서     서울시 강북구 오패산로 406      \nhttps://www.smpa.go.kr/gb/\n
# 4    서울강서경찰서       서울시 강서구 화곡로 308     \nhttps://www.smpa.go.kr/gs/\n
# 5    서울관악경찰서     서울시 관악구 관악로5길 33      \nhttps://www.smpa.go.kr/ga/\n
# 6    서울광진경찰서       서울시 광진구 자양로 167     \nhttps://www.smpa.go.kr/gj/\n
# 7    서울구로경찰서     서울시 구로구 가마산로 235      \nhttps://www.smpa.go.kr/gr/\n
# 8    서울금천경찰서    서울시 금천구 시흥대로73길 50     \nhttps://www.smpa.go.kr/gc/\n
# 9   서울남대문경찰서      서울시 중구 한강대로 410     \nhttps://www.smpa.go.kr/ndm/\n
# 10   서울노원경찰서       서울시 노원구 노원로 283     \nhttps://www.smpa.go.kr/nw/\n
# 11   서울도봉경찰서      서울시 도봉구 노해로 403      \nhttps://www.smpa.go.kr/db/\n
# 12  서울동대문경찰서  서울시 동대문구 약령시로21길 29     \nhttps://www.smpa.go.kr/ddm/\n
# 13   서울동작경찰서     서울시 동작구 노량진로 148      \nhttps://www.smpa.go.kr/dj/\n
# 14   서울마포경찰서     서울시 마포구 마포대로 183      \nhttps://www.smpa.go.kr/mp/\n
# 15   서울방배경찰서      서울시 서초구 동작대로 204     \nhttps://www.smpa.go.kr/bb/\n
# 16  서울서대문경찰서       서울 서대문구 통일로 113    \nhttps://www.smpa.go.kr/sdm/\n
# 17   서울서부경찰서        서울시 은평구 진흥로 58  \nhttps://www.smpa.go.kr/seobu/\n
# 18   서울서초경찰서     서울시 서초구 반포대로 179      \nhttps://www.smpa.go.kr/sc/\n
# 19   서울성동경찰서     서울시 성동구 왕십리광장로 9      \nhttps://www.smpa.go.kr/sd/\n
# 20   서울성북경찰서        서울 성북구 보문로 170     \nhttps://www.smpa.go.kr/sb/\n
# 21   서울송파경찰서       서울시 송파구 중대로 221     \nhttps://www.smpa.go.kr/sp/\n
# 22   서울수서경찰서       서울시 강남구 개포로 617     \nhttps://www.smpa.go.kr/ss/\n
# 23   서울양천경찰서      서울시 양천구 목동동로 99      \nhttps://www.smpa.go.kr/yc/\n
# 24  서울영등포경찰서     서울시 영등포구 국회대로 608    \nhttps://www.smpa.go.kr/ydp/\n
# 25   서울용산경찰서     서울시 용산구 원효로89길 24     \nhttps://www.smpa.go.kr/ys/\n
# 26   서울은평경찰서       서울시 은평구 연서로 365     \nhttps://www.smpa.go.kr/ep/\n
# 27   서울종로경찰서        서울시 종로구 율곡로 46     \nhttps://www.smpa.go.kr/jn/\n
# 28   서울종암경찰서       서울시 성북구 종암로 135     \nhttps://www.smpa.go.kr/ca/\n
# 29   서울중랑경찰서  서울시 중랑구 신내역로3길 40-10    \nhttps://www.smpa.go.kr/jnp/\n
# 30   서울중부경찰서        서울시 중구 수표로 27      \nhttps://www.smpa.go.kr/cb/\n
# 31   서울혜화경찰서  서울시 종로구 창경궁로 112-16      \nhttps://www.smpa.go.kr/hh/\n

# %%
# kakao_key를 통해서 서울지역 관서들의 위도 경도 좌표 구하기
local_url = 'https://dapi.kakao.com/v2/local/search/address.json'
headers = {"Authorization": "KakaoAK " + kakao_key}

lngs, lats = [], []
for i in df.index:
    url = f'{local_url}?query={quote(df.주소[i])}'
    result = requests.get(url, headers = headers).json()['documents']
    try:
        lngs.append(float(result[0]['x']))
        lats.append(float(result[0]['y']))
    except:
        print(df.관서명[i]) # 만약 일치하는 주소가 없으면 관서명 프린트
# Out:
# 서울종암경찰서

# %%
# '서울종암경찰서' 주소 확인
df[df.관서명.isin(['서울종암경찰서'])].주소
# Out:
# 28    서울시 성북구 종암로 135
# Name: 주소, dtype: object

# %%
# kakao에 주소가 있는지 확인
url = f"{local_url}?query={quote('서울시 성북구 종암로 135')}"
result = requests.get(url, headers=headers).json()
result
# Out:
# {'documents': [],
#  'meta': {'is_end': True, 'pageable_count': 0, 'total_count': 0}}

# %%
# 관서명으로 검색
local_url = 'https://dapi.kakao.com/v2/local/search/keyword.json'
headers = {"Authorization": "KakaoAK " + kakao_key}
url = f'{local_url}?query={quote("서울종암경찰서")}'
result = requests.get(url, headers = headers).json()['documents']

result
# Out:
# [{'address_name': '서울 성북구 하월곡동 27-5',
#   'category_group_code': 'PO3',
#   'category_group_name': '공공기관',
#   'category_name': '사회,공공기관 > 행정기관 > 경찰서',
#   'distance': '',
#   'id': '12803852',
#   'phone': '182',
#   'place_name': '서울종암경찰서',
#   'place_url': 'http://place.map.kakao.com/12803852',
#   'road_address_name': '서울 성북구 화랑로7길 32',
#   'x': '127.04013000033655',
#   'y': '37.603700560962736'},
#  {'address_name': '서울 성북구 종암동 3-1260',
#   'category_group_code': 'PO3',
#   'category_group_name': '공공기관',
#   'category_name': '사회,공공기관 > 행정기관 > 경찰서',
#   'distance': '',
#   'id': '572822781',
#   'phone': '182',
#   'place_name': '서울종암경찰서 (2024년 신축예정)',
#   'place_url': 'http://place.map.kakao.com/572822781',
#   'road_address_name': '',
#   'x': '127.032265443516',
#   'y': '37.6020199230987'},
#  {'address_name': '서울 성북구 종암동 25-47',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '사회,공공기관 > 행정기관부속시설',
#   'distance': '',
#   'id': '27540536',
#   'phone': '02-3396-7633',
#   'place_name': '서울종암경찰서 종암교통센터',
#   'place_url': 'http://place.map.kakao.com/27540536',
#   'road_address_name': '서울 성북구 종암로 45',
#   'x': '127.0356772521',
#   'y': '37.5944253884375'},
#  {'address_name': '서울 성북구 종암동 80-9',
#   'category_group_code': 'PO3',
#   'category_group_name': '공공기관',
#   'category_name': '사회,공공기관 > 행정기관 > 경찰서 > 파출소',
#   'distance': '',
#   'id': '21267659',
#   'phone': '02-3396-7690',
#   'place_name': '종암파출소',
#   'place_url': 'http://place.map.kakao.com/21267659',
#   'road_address_name': '서울 성북구 종암로23길 52',
#   'x': '127.03126356250864',
#   'y': '37.60009567675597'},
#  {'address_name': '서울 성북구 종암동 15-27',
#   'category_group_code': 'PO3',
#   'category_group_name': '공공기관',
#   'category_name': '사회,공공기관 > 행정기관 > 경찰서 > 치안센터',
#   'distance': '',
#   'id': '8510958',
#   'phone': '',
#   'place_name': '종암2치안센터',
#   'place_url': 'http://place.map.kakao.com/8510958',
#   'road_address_name': '서울 성북구 종암로 88',
#   'x': '127.03509247804305',
#   'y': '37.598193509571765'},
#  {'address_name': '서울 성북구 하월곡동 90-1152',
#   'category_group_code': 'PO3',
#   'category_group_name': '공공기관',
#   'category_name': '사회,공공기관 > 행정기관 > 경찰서 > 지구대',
#   'distance': '',
#   'id': '27331848',
#   'phone': '02-3396-7682',
#   'place_name': '월곡지구대',
#   'place_url': 'http://place.map.kakao.com/27331848',
#   'road_address_name': '서울 성북구 종암로32길 5',
#   'x': '127.032420501473',
#   'y': '37.6044309306415'},
#  {'address_name': '서울 성북구 석관동 407-3',
#   'category_group_code': 'PO3',
#   'category_group_name': '공공기관',
#   'category_name': '사회,공공기관 > 행정기관 > 경찰서 > 파출소',
#   'distance': '',
#   'id': '10491907',
#   'phone': '02-3396-7660',
#   'place_name': '석관파출소',
#   'place_url': 'http://place.map.kakao.com/10491907',
#   'road_address_name': '서울 성북구 화랑로32가길 20',
#   'x': '127.05527720328959',
#   'y': '37.608961624584424'},
#  {'address_name': '서울 성북구 장위동 275-18',
#   'category_group_code': 'PO3',
#   'category_group_name': '공공기관',
#   'category_name': '사회,공공기관 > 행정기관 > 경찰서 > 지구대',
#   'distance': '',
#   'id': '10728952',
#   'phone': '02-3396-7670',
#   'place_name': '장위지구대',
#   'place_url': 'http://place.map.kakao.com/10728952',
#   'road_address_name': '서울 성북구 장월로 174',
#   'x': '127.05376939149967',
#   'y': '37.61942279830535'}]

# %%
# 주소가 없는경우 관서명으로 검색 후 위도, 경도 구하기
headers = {"Authorization": "KakaoAK " + kakao_key}

lngs, lats = [], []
for i in df.index:
    url = f'https://dapi.kakao.com/v2/local/search/address.json?query={quote(df.주소[i])}'
    result = requests.get(url, headers = headers).json()['documents']
    try:
        lngs.append(float(result[0]['x']))
        lats.append(float(result[0]['y']))
    except:
        try:
            url = f'https://dapi.kakao.com/v2/local/search/keyword.json?query={quote(df.관서명[i])}'
            result = requests.get(url, headers = headers).json()['documents']
            lngs.append(float(result[0]['x']))
            lats.append(float(result[0]['y']))
        except:
            print(df.관서명[i])

# %%
df['위도'] = lats
df['경도'] = lngs
df.head()
# Out:
#         관서명                    주소                            홈페이지         위도  \
# 0  서울특별시경찰청     서울시 종로구 사직로8길 31      \nhttps://www.smpa.go.kr/\n  37.574946
# 1   서울강남경찰서  서울시 강남구 테헤란로 114길 11  \nhttps://www.smpa.go.kr/gn/\n  37.509367
# 2   서울강동경찰서        서울시 강동구 성내로 57  \nhttps://www.smpa.go.kr/gd/\n  37.528678
# 3   서울강북경찰서     서울시 강북구 오패산로 406   \nhttps://www.smpa.go.kr/gb/\n  37.637170
# 4   서울강서경찰서       서울시 강서구 화곡로 308  \nhttps://www.smpa.go.kr/gs/\n  37.551558
#
#            경도
# 0  126.971980
# 1  127.067100
# 2  127.126957
# 3  127.027042
# 4  126.849656

# %% [markdown]
# ## 2. 전국의 경찰서 정보 가져오기

# %%
# 전국 지역의 수
count= len(soup.select('.nav.nav-tabs.ui-multi-line > li'))
count
# Out:
# 18

# %%
lines = []
for i in range(1, count + 1):
    # 페이지 이동
    driver.find_element(By.ID, f'tab_{i}').click()
    time.sleep(3)
    
    # 각 페이지의 데이터 추출
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    lis = soup.select('tbody > tr')
    
    for li in lis:
        title = li.select('.show-col')[0].text
        addr = li.select('.show-col')[1].text
        href = li.select('.show-col')[2].text

        lines.append([title, addr, href])

# %%
df = pd.DataFrame(lines, columns=['관서명', '주소', '홈페이지'])
df
# Out:
#             관서명                     주소  \
# 0      서울특별시경찰청      서울시 종로구 사직로8길 31
# 1       서울강남경찰서   서울시 강남구 테헤란로 114길 11
# 2       서울강동경찰서         서울시 강동구 성내로 57
# 3       서울강북경찰서      서울시 강북구 오패산로 406
# 4       서울강서경찰서        서울시 강서구 화곡로 308
# ..          ...                    ...
# 272       합천경찰서  경남 합천군 합천읍 황강체육공원로 67
# 273  제주특별자치도경찰청          제주시 수목원 서길 37
# 274      서귀포경찰서            서귀포시 신중로 27
# 275     제주동부경찰서             제주시 동광로 66
# 276     제주서부경찰서       제주시 애월읍 애조로  215
#
#                                         홈페이지
# 0                \nhttps://www.smpa.go.kr/\n
# 1             \nhttps://www.smpa.go.kr/gn/\n
# 2             \nhttps://www.smpa.go.kr/gd/\n
# 3             \nhttps://www.smpa.go.kr/gb/\n
# 4             \nhttps://www.smpa.go.kr/gs/\n
# ..                                       ...
# 272        \nhttps://www.gnpolice.go.kr/hc\n
# 273           \nhttps://www.jjpolice.go.kr\n
# 274  \nhttps://www.jjpolice.go.kr/seogwipo\n
# 275    \nhttps://www.jjpolice.go.kr/dongbu\n
# 276     \nhttps://www.jjpolice.go.kr/seobu\n
#
# [277 rows x 3 columns]

# %%
driver.close()

# %%
# 주소가 없는경우 관서명으로 검색 후 위도, 경도 구하기
headers = {"Authorization": "KakaoAK " + kakao_key}

lngs, lats = [], []
for i in df.index:
    url = f'https://dapi.kakao.com/v2/local/search/address.json?query={quote(df.주소[i])}'
    result = requests.get(url, headers = headers).json()['documents']
    try:
        lngs.append(float(result[0]['x']))
        lats.append(float(result[0]['y']))
    except:
        try:
            url = f'https://dapi.kakao.com/v2/local/search/keyword.json?query={quote(df.관서명[i])}'
            result = requests.get(url, headers = headers).json()['documents']
            lngs.append(float(result[0]['x']))
            lats.append(float(result[0]['y']))
        except:
            print(df.관서명[i])

# %%
# df에 위도, 경도를 추가
df['위도'] = lats
df['경도'] = lngs
df.head()
# Out:
#         관서명                    주소                            홈페이지         위도  \
# 0  서울특별시경찰청     서울시 종로구 사직로8길 31      \nhttps://www.smpa.go.kr/\n  37.574946
# 1   서울강남경찰서  서울시 강남구 테헤란로 114길 11  \nhttps://www.smpa.go.kr/gn/\n  37.509367
# 2   서울강동경찰서        서울시 강동구 성내로 57  \nhttps://www.smpa.go.kr/gd/\n  37.528678
# 3   서울강북경찰서     서울시 강북구 오패산로 406   \nhttps://www.smpa.go.kr/gb/\n  37.637170
# 4   서울강서경찰서       서울시 강서구 화곡로 308  \nhttps://www.smpa.go.kr/gs/\n  37.551558
#
#            경도
# 0  126.971980
# 1  127.067100
# 2  127.126957
# 3  127.027042
# 4  126.849656

# %%
df.to_csv('전국경찰관서.csv', index=False)

# %% [markdown]
# ## 3. 지도에 표시하기

# %%
map = folium.Map(location=[df.위도.mean(), df.경도.mean()], zoom_start=8)
for i in df.index[:]:
    folium.Marker(
        location=[df.위도[i],df.경도[i]], 
        popup=folium.Popup(df.주소[i], max_width=200), 
        tooltip=df.관서명[i],
        icon = folium.Icon(icon = 'glyphicon glyphicon-star')
    ).add_to(map)
title = '<h3 align="center" style="font-size:20px">전국 경찰관서 위치</h3>'
map.get_root().html.add_child(folium.Element(title))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7ff3f87fae0b8b0b801b3f6059784df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;전국 경찰관서 위치&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7ff3f87fae0b8b0b801b3f6059784df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b7ff3f87fae0b8b0b801b3f6059784df = L.map(
#                 &quot;map_b7ff3f87fae0b8b0b801b3f6059784df&quot;,
#                 {
#                     center: [36.42075293977509, 127.61759192094708],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ff43c1a5c6b977b88099fcd54204f11 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b7ff3f87fae0b8b0b801b3f6059784df);
#
#
#             var marker_081ae63c4096eab6e4aed64ebf932fad = L.marker(
#                 [37.5749462708923, 126.971979688446],
#                 {}
#             ).addTo(map_b7ff3f87fae0b8b0b801b3f6059784df);
#
#
#             var icon_88de54eb0e4b418eaf367ae78f6d5ca6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_081ae63c4096eab6e4aed64ebf932fad.setIcon(icon_88de54eb0e4b418eaf367ae78f6d5ca6);
#
#
#         var popup_1c19e16c0b2e697a5a26fbdc98a6ee90 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_0935d1d0c66079a995d56667b017c734 = $(`&lt;div id=&quot;html_0935d1d0c66079a995d56667b017c734&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울시 종로구 사직로8길 31 &lt;/div&gt;`)[0];
#                 popup_1c19e16c0b2e697a5a26fbdc98a6ee90.setContent(html_0935d1d0c66079a995d56667b017c734);
#
#
#
#         marker_081ae63c4096eab6e4aed64ebf932fad.bindPopup(popup_1c19e16c0b2e697a5a26fbdc98a6ee90)
#         ;
#
#
#
#
#             marker_081ae63c4096eab6e4aed64ebf932fad.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시경찰청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d2265f8af4400147cc3ee885fdf1258b = L.marker(
#                 [37.5093666837584, 127.067099927292],
#                 {}
#             ).addTo(map_b7ff3f87fae0b8b0b801b3f6059784df);
#
#
#             var icon_1cc51c4a32c80e56bd9ff286e51e51b8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d2265f8af4400147cc3ee885fdf1258b.setIcon(icon_1cc51c4a32c80e56bd9ff286e51e51b8);
#
#
#         var popup_519d9c8c4f928da425b21930c28e15e3 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_d5d7a864a1651579a6c6824626fb76a2 = $(`&lt;div id=&quot;html_d5d7a864a1651579a6c6824626fb76a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울시 강남구 테헤란로 114길 11&lt;/div&gt;`)[0];
#                 popup_519d9c8c4f928da425b21930c28e15e3.setContent(html_d5d7a864a1651579a6c6824626fb76a2);
#
#
#
#         marker_d2265f8af4400147cc3ee885fdf1258b.bindPopup(popup_519d9c8c4f928da425b21930c28e15e3)
#         ;
#
#
#
#
#             marker_d2265f8af4400147cc3ee885fdf1258b.bindTooltip(
#                 `&lt;div&gt;
#                      서울강남경찰서
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fd899397af5d959f7c51e19ecaff1208 = L.marker(
#                 [37.5286775394179, 127.126957376122],
#                 {}
#             ).addTo(map_b7ff3f87fae0b8b0b801b3f6059784df);
#
#
#             var icon_1c4254d60cc74794db7db8393190f160 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fd899397af5d959f7c51e19ecaff1208.setIcon(icon_1c4254d60cc74794db7db8393190f160);
#
#
#         var popup_04054b0e5cc346cd5d1c7fdfc9d87815 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_16edc583876ccab71f0232cf6ff85a2c = $(`&lt;div id=&quot;html_16edc583876ccab71f0232cf6ff85a2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울시 강동구 성내로 57&lt;/div&gt;`)[0];
