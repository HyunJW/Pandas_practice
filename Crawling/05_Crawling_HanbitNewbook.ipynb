# %% [markdown]
# # 한빛 아카데미 - 새로나온 책 10page
# * https://www.hanbit.co.kr/academy/books/new_book_list.html
# * 제목 / 저자 / 번역 / 출간일 / 쪽수 / 판매가

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm.notebook import tqdm

# %%
base_url = 'https://www.hanbit.co.kr'
sub_url = '/academy/books/new_book_list.html'
url = base_url + sub_url + '?page=' + str(1)
req = requests.get(url)
soup = BeautifulSoup(req.text, 'html.parser')

# %% [markdown]
# # 1. 찾으려고 하는 목록 데이터

# %%
lis = soup.select('li.sub_book_list')
len(lis)
# Out:
# 20

# %% [markdown]
# ##  하나의 데이터로 원하는 정보를 추출

# %%
li = lis[0]

# %%
# 서브 페이지의 링크 추출
href = li.find('a')['href']
href
# Out:
# '/academy/books/book_view.html?p_code=B5620881464'

# %%
# sub page로 이동해서 원하는 정보를 추출
sub_req = requests.get(base_url + href)
sub_soup = BeautifulSoup(sub_req.text, 'html.parser')
sub_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <!--[if lte IE 8]>
# <script>
#   location.replace('/support/explorer_upgrade.html');
# </script>
# <![endif]-->
# <meta charset="utf-8"/>
# <title>STEM CookBook, 전기 및 하이브리드 자동차(3판)</title>
# <link href="https://www.hanbit.co.kr/images/common/hanbit.ico" rel="shortcut icon"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="website" property="og:type"/>
# <meta content="STEM CookBook, 전기 및 하이브리드 자동차(3판)" property="og:title"/>
# <meta content="이 책은 친환경자동차 중 가장 보편적인 전기 차량(EV)과 하이브리드 차량(HEV)에 대한 전반적인 개념과 원리를 소개한다." property="og:description"/>
# <meta content="https://www.hanbit.co.kr/data/books/B5620881464_m.jpg" property="og:image"/>
# <meta content="https://www.hanbit.co.kr/academy/books/book_view.html?p_code=B5620881464" property="og:url"/>
# <link href="https://www.hanbit.co.kr/academy/books/book_view.html?p_code=B5620881464" rel="canonical">
# <meta content="전기자동차,하이브리드 자동차,친환경자동차,EV,HEV,ICEV,모터,발전기,배터리,전기 기계" name="keywords"/>
# <meta content="이 책은 친환경자동차 중 가장 보편적인 전기 차량(EV)과 하이브리드 차량(HEV)에 대한 전반적인 개념과 원리를 소개한다." name="description"/>
# <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0" name="viewport"/>
# <meta content="width=1260" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable">
# <meta content="01c29ed1852aecca7a48ac0c3e0869627bc512d8" name="naver-site-verification">
# <link href="/css/common.css?20210603093421" rel="stylesheet"/>
# <link href="/css/hover.css" media="all" rel="stylesheet"/>
# <link href="/js/jquery.raty.css" rel="stylesheet">
# <script src="/js/jquery-latest.js" type="text/javascript"></script>
# <script src="/js/jquery-ui.js" type="text/javascript"></script>
# <script src="/js/jquery.event.drag-1.5.min.js" type="text/javascript"></script>
# <script src="/js/jquery.touchSlider.js" type="text/javascript"></script>
# <script src="/js/jquery.raty.js" type="text/javascript"></script>
# <script src="/js/main.js" type="text/javascript"></script>
# <script src="/lib/cheditor/cheditor.js" type="text/javascript"></script>
# <script src="/js/jquery.ui.datepicker-ko.js" type="text/javascript"></script>
# <script src="/js/engine.js" type="text/javascript"></script>
# <script src="/js/vue.js" type="text/javascript"></script>
# <!-- Google Analytics -->
# <script>
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# ga('create', 'UA-47080738-1', 'hanbit.co.kr');
# ga('require', 'linkid', 'linkid.js');
# ga('send', 'pageview');
# </script>
# <!-- Google Analytics -->
# <!-- Facebook Pixel Code -->
# <script>
#   !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '406459623338891');
#   fbq('track', 'PageView');
# </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=406459623338891&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-W9D5PM3');</script>
# <!-- End Google Tag Manager -->
# <!-- Kakao Pixel Code -->
# <script charset="UTF-8" src="//t1.daumcdn.net/adfit/static/kp.js" type="text/javascript"></script>
# <script type="text/javascript">
#   kakaoPixel('3011392806152551233').pageView();
#   kakaoPixel('3011392806152551233').viewContent({
#     id: 'B5620881464'
#   });
# </script>
# <!-- //Kakao Pixel Code -->
# </link></meta></meta></link></head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-W9D5PM3" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <link href="/academy/css/layout-academy.css?202204141945" rel="stylesheet"/>
# <link href="/academy/css/layout-books.css" rel="stylesheet"/>
# <link href="/academy/css/layout-community.css" rel="stylesheet"/>
# <link href="/academy/css/layout-network.css" rel="stylesheet"/>
# <link href="/css/layout-member.css" rel="stylesheet"/>
# <!-- 메뉴 바로가기 -->
# <div id="quick_skip_menu">
# <a href="#gnb" onclick="document.getElementById('gnb').tabIndex = -1;document.getElementById('gnb').focus();return false;"><span>메뉴 바로가기</span></a>
# <a href="#top_search" onclick="view_hover('main_search_area','','show'), document.getElementById('top_search').tabIndex = -1;document.getElementById('top_search').focus();return false;"><span>검색 및 카테고리 바로가기</span></a>
# <a href="#main_top_box" onclick="document.getElementById('main_top_box').tabIndex = -1;document.getElementById('main_top_box').focus();return false;"><span>프로모션 바로가기</span></a>
# <a href="#main_book_area" onclick="document.getElementById('main_book_area').tabIndex = -1;document.getElementById('main_book_area').focus();return false;"><span>책 바로가기</span></a>
# <a href="#main_network_area" onclick="document.getElementById('main_network_area').tabIndex = -1;document.getElementById('main_network_area').focus();return false;"><span>네트워크 바로가기</span></a>
# </div>
# <!-- //메뉴 바로가기 -->
# <!-- header -->
# <header>
# <!-- top menu -->
# <nav>
# <div id="wrap_nav">
# <ul class="top_brand">
# <li><a href="https://www.hanbit.co.kr/index.html" name="hanbit_network"><span>HOME</span></a></li>
# <li><a href="https://www.hanbit.co.kr/media/">한빛미디어</a></li>
# <li><a href="https://www.hanbit.co.kr/academy/">한빛아카데미</a></li>
# <li><a href="https://www.hanbit.co.kr/biz/">한빛비즈</a></li>
# <li><a href="https://www.hanbit.co.kr/life/">한빛라이프</a></li>
# <li><a href="https://www.hanbit.co.kr/edu/">한빛에듀</a></li>
# <li><a href="https://www.hanbit.co.kr/realtime/">리얼타임</a></li>
# <li><a href="https://www.hanbit.co.kr/textbook/" target="_blank">한빛정보교과서</a></li>
# <li><a href="https://www.hanbit.co.kr/rent/" target="_blank">한빛대관서비스</a></li>
# </ul>
# <ul class="top_menu">
# <li><a class="login" href="https://www.hanbit.co.kr/member/login.html">로그인</a></li>
# <li><a class="join" href="https://www.hanbit.co.kr/member/member_agree.html">회원가입</a></li>
# <li><a class="myhanbit" href="https://www.hanbit.co.kr/myhanbit/myhanbit.html">마이한빛</a></li>
# <li><a class="cart" href="https://www.hanbit.co.kr/myhanbit/cart.html">장바구니</a></li>
# <li class="top_menu_store"><a href="https://www.hanbit.co.kr/publisher/foreignrights.html?lang=e" target="_blank">ENGLISH</a></li>
# </ul>
# </div>
# </nav>
# <!-- //top menu -->
# <div id="wrap_gnb">
# <!-- logo -->
# <h1><a href="https://www.hanbit.co.kr/academy/">한빛아카데미</a></h1>
# <!-- //logo -->
# <!-- Menu -->
# <div id="gnb" name="gnb">
# <ul>
# <li><a class="" href="https://www.hanbit.co.kr/academy/info/info.html">브랜드 소개</a></li>
# <li><a class="curr" href="https://www.hanbit.co.kr/academy/books/new_book_list.html">책</a></li>
# <li><a class="" href="https://www.hanbit.co.kr/academy/channel/list.html">채널.H</a></li>
# <li><a class="" href="https://www.hanbit.co.kr/academy/professor/index.html">교수전용공간</a></li>
# <!--
#         <li><a href="https://www.hanbit.co.kr/academy/electric/electric_book_list.html" class="">전기수험서</a></li>
#         -->
# <!-- <li><a href="https://www.hanbit.co.kr/academy/community/index.html" class="">커뮤니티</a></li>-->
# <li><a class="" href="https://www.hanbit.co.kr/support/help_info.html" target="_blank">고객지원</a></li>
# <li class="search" id="top_search"><a href="javascript:;" onclick="view_hover('main_search_area','','show'); $('#keyword_str').focus();"><span>SERACH</span></a></li>
# </ul>
# </div>
# <!-- //Menu -->
# <!-- lnb -->
# <div class="lnb" style="top:92px;">
# <div class="lnb_area">
# <!-- 책 -->
# <ul class="lnb_depth1_category">
# <li onmouseout="view_hover('category_books','','hide')" onmouseover="view_hover('category_books','','show')"><a class="gnb_category" href="#" onfocus="view_hover('category_books','','show')">카테고리
# </a>
# <ul id="category_books">
# <li><a href="https://www.hanbit.co.kr/academy/books/category_list.html?cate_cd=004003">수학/통계</a></li>
# <li><a href="https://www.hanbit.co.kr/academy/books/category_list.html?cate_cd=004010">과학/공학일반</a></li>
# <li><a href="https://www.hanbit.co.kr/academy/books/category_list.html?cate_cd=004007">컴퓨터공학</a></li>
# <li><a href="https://www.hanbit.co.kr/academy/books/category_list.html?cate_cd=004004">프로그래밍</a></li>
# <li><a href="https://www.hanbit.co.kr/academy/books/category_list.html?cate_cd=004011">데이터과학/인공지능</a></li>
# <li><a href="https://www.hanbit.co.kr/academy/books/category_list.html?cate_cd=004008">전기/전자</a></li>
# <li><a href="https://www.hanbit.co.kr/academy/books/category_list.html?cate_cd=004009">기계/자동차</a></li>
# <li><a href="https://www.hanbit.co.kr/academy/books/category_list.html?cate_cd=004006">OA/그래픽</a></li>
# <li><a href="https://www.hanbit.co.kr/academy/books/category_list.html?cate_cd=004012">경영/경제</a></li>
# <li><a href="https://www.hanbit.co.kr/academy/books/category_list.html?cate_cd=004005">논문</a></li>
# <!--li onmouseover="view_hover('category_books01','','show')" onMouseOut="view_hover('category_books01','','hide')"><a href="#" onFocus="view_hover('category_books01','','show')">1차 카테고리</a>
#                 <ul id="category_books01">
#                   <li><a href="#">2차 카테고리 1</a></li>
#                   <li><a href="#">2차 카테고리 2</a></li>
#                 </ul>
#               </li>
#               <li onmouseover="view_hover('category_books02','','show')" onMouseOut="view_hover('category_books02','','hide')"><a href="#" onFocus="view_hover('category_books02','','show')">1차 카테고리</a>
#                 <ul id="category_books02">
#                   <li><a href="#">2차 카테고리 1</a></li>
#                   <li><a href="#">2차 카테고리 2</a></li>
#                 </ul>
#               </li-->
# <!-- 항상 노출 메뉴 -->
# <!--
#               <li class="gnb_category_series"><a href="https://www.hanbit.co.kr/academy/books/series_list.html">시리즈</a></li>
#               <li class="gnb_category_full"><a href="https://www.hanbit.co.kr/academy/books/full_book_list.html">전체도서목록</a></li>
#               -->
# </ul>
# </li>
# </ul>
# <ul class="lnb_depth1">
# <li><a href="https://www.hanbit.co.kr/academy/books/new_book_list.html">새로나온책</a></li><span>l</span>
# <li><a href="https://www.hanbit.co.kr/academy/books/bestseller_list.html">베스트셀러</a></li><span>l</span>
# <li><a href="https://www.hanbit.co.kr/academy/books/series_list.html">시리즈</a></li><span>l</span>
# <li><a href="https://www.hanbit.co.kr/academy/books/full_book_list.html">전체도서목록</a></li>
# <!--
#           <li><a href="https://www.hanbit.co.kr/academy/books/forthcoming_list.html">출간예정도서</a></li>
#           -->
# <!-- add by coffin, 2016-04-25
#           <li><a href="https://www.hanbit.co.kr/academy/books/road_map.html">학습로드맵</a></li>
#           -->
# </ul>
# <!-- //책 -->
# </div>
# </div>
# <!-- //lnb -->
# </div>
# </header>
# <!-- //header -->
# <!-- 메인 검색 및 카테고리 영역 -->
# <div class="fixed" id="main_search_area" style="display:none;">
# <div class="msa_wrap">
# <!-- 검색 -->
# <div class="msa_srch_wrap">
# <form onsubmit="return false;">
# <fieldset class="msa_srch_field">
# <legend>한빛출판네트워크 검색</legend>
# <input @input="typeKeyword" accesskey="s" autocomplete="off" class="srch_keyword" id="keyword_str" name="keyword_str" title="검색어" type="text" v-model="keyword"/>
# <input @click="clickSearch" class="srch_btn" style="cursor:pointer;" type="submit"/>
# </fieldset>
# </form>
# </div>
# <!-- //검색 -->
# <!-- ① 인기검색어 -->
# <div class="msa_srch_polular" v-if="showPopularKeyword === true">
# <h2 class="tit">인기 검색어 <span>(최근 1개월간)</span></h2>
# <div class="popula_box">
# <ul class="left">
# <li v-for="keyword in leftPopularKeywordList">
# <a :class="keyword.bold" @click="clickPopularKeyword(keyword)">
#                   {{ keyword.number }} {{ keyword.bookName }}
#               </a>
# </li>
# </ul>
# <ul class="right">
# <li v-for="keyword in rightPopularKeywordList">
# <a :class="keyword.bold" @click="clickPopularKeyword(keyword)">
#                   {{ keyword.number }} {{ keyword.bookName }}
#               </a>
# </li>
# </ul>
# </div>
# </div>
# <!-- ① 인기검색어 -->
# <!-- ② 검색결과/검색서제스쳔 -->
# <div class="msa_srch_suggestion" v-if="showPopularKeyword === false">
# <div class="sugg_left" v-if="bookList.length !== 0">
# <h3 class="tit">BOOK</h3>
# <ul class="books_list">
# <li @mouseover="mouseOverBook(book.id)" v-for="book in bookList"><a @click="clickBookKeyword(book)"><p v-html="book.name"></p></a></li>
# </ul>
# </div>
# <div class="sugg_right">
# <div class="sugg_book" v-if="bookList.length !== 0">
# <table class="sugg_book_detail">
# <tr>
# <td class="cover">
# <a @click="clickBookKeyword(bookSummary)">
# <img :src="bookSummary.imgUrl" class="b_cover"/>
# </a>
# </td>
# <td class="draft">
# <a @click="clickBookKeyword(bookSummary)" class="b_title"><strong v-html="bookSummary.originName"></strong></a>
# <p class="b_int">
#                 {{ bookSummary.author }} 지음<br/>
#                 {{ bookSummary.publishingCompany }} | {{ bookSummary.date }}
#                 </p>
# <p class="b_type">
# <span>{{ bookSummary.bookType }}</span>
# </p>
# </td>
# </tr>
# </table>
# </div>
# <!--
#         <div class="sugg_edu" v-if="educationList.length !== 0">
#           <h3 class="tit">EDUCATION</h3>
#           <ul class="edu_list">
#             <li v-for="education in educationList">&#149; <a @click="clickEducationKeyword(education)"><span v-html="education.title"></span></a></li>
#           </ul>
#         </div>
#         -->
# <div class="sugg_cont" v-if="contentList.length !== 0">
# <h3 class="tit">CONTENTS</h3>
# <ul class="cont_list">
# <li v-for="content in contentList">• <a @click="clickContentKeyword(content)"><span v-html="content.title"></span></a></li>
# </ul>
# </div>
# </div>
# </div>
# <!-- //② 검색결과/검색서제스쳔 -->
# <!-- 닫기 -->
# <div class="msa_wrap_close">
# <a href="javascript:;" onclick="view_hover('main_search_area','','hide')">닫기</a>
# </div>
# <!-- //닫기 -->
# </div>
# </div>
# <script type="text/javascript">
#     "use strict";
#
#     var common_top_search_vue = new Vue({
#         el: '#main_search_area',
#         data: {
#             //검색엔진 URL
#             searchProxyURL: "https://search.hanbit.co.kr",
#             //인기 검색어 show 여부
#             showPopularKeyword: true,
#             //사용자 검색 키워드
#             keyword: '',
#             //인기 검색어 리스트
#             popularKeywordList: [],
#             // 인기 검색어 리스트 (왼쪽)
#             leftPopularKeywordList: [],
#             // 인기 검색어 리스트 (오른쪽)
#             rightPopularKeywordList: [],
#             // 자동완성에서의 책 리스트
#             bookList: [],
#             // 자동완성에서의 책 정보
#             bookSummary: {
#                 'imgUrl': '',
#                 'link': '',
#                 'name': '',
#                 'author': '',
#                 'publishingCompany': '',
#                 'date': '',
#                 'bookType': ''
#             },
#             //에듀케이션 리스트
#             educationList: [],
#             //컨텐츠 리스트
#             contentList: []
#         },
#         created: function created() {
#             // 인기 검색어 조회
#             this.getPopularKeyword();
#         },
#         methods: {
#             /**
#              * 사용자가 검색 키워드를 입력할때 발생하는 이벤트
#              */
#             typeKeyword: function typeKeyword() {
#                 var self = this;
#                 var keyword = $("#keyword_str").val();
#
#                 if (keyword.length !== 0) {
#                     //자동완성어
#                     this.findAutocompleteResult(keyword);
#                 } else {
#                     //인기검색어
#                     self.showPopularKeyword = true;
#                 }
#             },
#
#             /**
#              * 인기검색어 조회
#              */
#             getPopularKeyword: function getPopularKeyword() {
#                 var self = this;
#                 this.popularKeywordList = [];
#                 $.get(this.searchProxyURL + "/querylog/popularKeyword").done(function (data) {
#                     if (data != null) {
#                         self.drawPopularKeyword(data);
#                     }
#                 });
#             },
#
#             /**
#              * 인기 검색어 그리기
#              */
#             drawPopularKeyword: function drawPopularKeyword(popularBooks) {
#                 var self = this;
#                 popularBooks.forEach(function (item) {
#                     var popularBook = {
#                         bookName: item.keyword
#                     };
#                     self.popularKeywordList.push(popularBook);
#                 });
#                 var number = 0;
#
#                 for (var _iterator = this.popularKeywordList, _isArray = Array.isArray(_iterator), _i = 0, _iterator = _isArray ? _iterator : _iterator[Symbol.iterator]();;) {
#                     var _ref;
#
#                     if (_isArray) {
#                         if (_i >= _iterator.length) break;
#                         _ref = _iterator[_i++];
#                     } else {
#                         _i = _iterator.next();
#                         if (_i.done) break;
#                         _ref = _i.value;
#                     }
#
#                     var keyword = _ref;
#                     number = number + 1;
#                     keyword.number = number.toString().length < 2 ? "0" + number : number;
#
#                     if (number > 5) {
#                         keyword.direction = "right";
#                         self.rightPopularKeywordList.push(keyword);
#                     } else {
#                         keyword.direction = "left";
#
#                         if (number < 4) {
#                             keyword.bold = 'active';
#                         }
#
#                         self.leftPopularKeywordList.push(keyword);
#                     }
#                 }
#             },
#
#             /**
#              * 자동완성 검색 결과
#              */
#             findAutocompleteResult: function findAutocompleteResult(keyword) {
#                 var self = this;
#                 var param = {
#                     q: keyword,
#                     types: "education,book,contents",
#                     fq: keyword
#                 };
#                 $.post(this.searchProxyURL + "/autocomplete/search", param).done(function (data) {
#                     if (data != null) {
#                         var bookResult = data.booksResults;
#                         self.changeBookList(keyword, bookResult);
#                         var contentResult = data.contentsResults;
#                         self.changeContentList(keyword, contentResult);
#                         var educationResult = data.educationResults;
#                         self.changeEducationList(keyword, educationResult);
#                     }
#                 });
#                 this.showPopularKeyword = false;
#             },
#
#             /**
#              * 자동완성어에서 BOOK 부분에서 마우스를 올렸을 시에 발생하는 이벤트
#              * @param bookId
#              */
#             mouseOverBook: function mouseOverBook(bookId) {
#                 var currentBook = this.bookList.filter(function (book) {
#                     return book.id === bookId;
#                 });
#                 this.changeBookSummary(currentBook[0]);
#             },
#
#             /**
#              * 책 소개 변경
#              * @param book
#              */
#             changeBookSummary: function changeBookSummary(book) {
#                 if (book !== {}) {
#                     this.bookSummary.name = book.name;
#                     this.bookSummary.originName = book.originName;
#                     this.bookSummary.author = book.author;
#                     this.bookSummary.bookType = book.bookType;
#                     this.bookSummary.imgUrl = book.imgUrl;
#                     this.bookSummary.link = book.link;
#                     this.bookSummary.publishingCompany = book.publishingCompany;
#                     this.bookSummary.date = book.date;
#                     this.bookSummary.bookType = book.bookType;
#                 }
#             },
#
#             /**
#              * BOOK 리스트 변경
#              */
#             changeBookList: function changeBookList(keyword, bookResultList) {
#                 var self = this;
#                 self.bookList = [];
#                 var index = 0;
#
#                 if (bookResultList != null) {
#                     for (var _iterator2 = bookResultList, _isArray2 = Array.isArray(_iterator2), _i2 = 0, _iterator2 = _isArray2 ? _iterator2 : _iterator2[Symbol.iterator]();;) {
#                         var _ref2;
#
#                         if (_isArray2) {
#                             if (_i2 >= _iterator2.length) break;
#                             _ref2 = _iterator2[_i2++];
#                         } else {
#                             _i2 = _iterator2.next();
#                             if (_i2.done) break;
#                             _ref2 = _i2.value;
#                         }
#
#                         var result = _ref2;
#
#                         if (index < 10) {
#                             var book = {};
#                             book.id = result.code;
#                             book.originName = result.title;
#                             book.name = JSON.parse(JSON.stringify(self.replaceHighlightWord(result.title, keyword)));
#                             book.link = result.code;
#                             book.imgUrl = self.getBookImageURL(result.code);
#                             book.author = result.author;
#                             book.publishingCompany = result.brand;
#                             book.date = result.pubDate;
#                             book.bookType = result.bookType;
#                             self.bookList.push(book); //책 미리보기 변경
#
#                             self.changeBookSummary(self.bookList[0]);
#                         }
#                     }
#                 } else {
#                     self.initBookSummary();
#                 }
#             },
#
#             /**
#              * 책 이미지 주소 가져오기
#              */
#             getBookImageURL: function getBookImageURL(bookCode) {
#                 var imgURL;
#
#                 if (bookCode.substr(0, 1) === "E") {
#                     imgURL = '/data/ebook/' + bookCode + '_m.jpg';
#                 } else {
#                     imgURL = '/data/books/' + bookCode + "_m.jpg";
#                 }
#
#                 return imgURL;
#             },
#
#             /**
#              * 검색 결과가 없을 경우 책 미리보기 초기화
#              */
#             initBookSummary: function initBookSummary() {
#                 this.bookSummary = {
#                     'imgUrl': '',
#                     'link': '',
#                     'name': '',
#                     'author': '',
#                     'publishingCompany': '',
#                     'date': '',
#                     'bookType': ''
#                 };
#             },
#
#             /**
#              * education 리스트 변경
#              */
#             changeEducationList: function changeEducationList(keyword, educationResultList) {
#                 var self = this;
#                 self.educationList = [];
#                 var index = 0;
#
#                 if (educationResultList != null) {
#                     for (var _iterator3 = educationResultList, _isArray3 = Array.isArray(_iterator3), _i3 = 0, _iterator3 = _isArray3 ? _iterator3 : _iterator3[Symbol.iterator]();;) {
#                         var _ref3;
#
#                         if (_isArray3) {
#                             if (_i3 >= _iterator3.length) break;
#                             _ref3 = _iterator3[_i3++];
#                         } else {
#                             _i3 = _iterator3.next();
#                             if (_i3.done) break;
#                             _ref3 = _i3.value;
#                         }
#
#                         var result = _ref3;
#
#                         if (index < 3) {
#                             var content = {};
#                             content.title = JSON.parse(JSON.stringify(self.replaceHighlightWord(result.title, keyword)));
#                             content.link = result.code;
#                             self.educationList.push(content);
#                             index = index + 1;
#                         }
#                     }
#                 }
#             },
#
#             /**
#              * contents 리스트 변경
#              */
#             changeContentList: function changeContentList(keyword, contentResult) {
#                 var self = this;
#                 self.contentList = [];
#                 var index = 0;
#
#                 if (contentResult != null) {
#                     for (var _iterator4 = contentResult, _isArray4 = Array.isArray(_iterator4), _i4 = 0, _iterator4 = _isArray4 ? _iterator4 : _iterator4[Symbol.iterator]();;) {
#                         var _ref4;
#
#                         if (_isArray4) {
#                             if (_i4 >= _iterator4.length) break;
#                             _ref4 = _iterator4[_i4++];
#                         } else {
#                             _i4 = _iterator4.next();
#                             if (_i4.done) break;
#                             _ref4 = _i4.value;
#                         }
#
#                         var result = _ref4;
#
#                         if (index < 7) {
#                             var content = {};
#                             content.title = JSON.parse(JSON.stringify(self.replaceHighlightWord(result.title, keyword)));
#                             content.link = result.code;
#                             self.contentList.push(content);
#                             index = index + 1;
#                         }
#                     }
#                 }
#             },
#
#             /**
#              * 하이라이트 표시
#              */
#             replaceHighlightWord: function replaceHighlightWord(str, highlightKeyword) {
#                 var replaceHighlightKeyword = highlightKeyword.replace(/[^a-z0-9가-힣_ ]/gi, '');
#                 var regEx = new RegExp(replaceHighlightKeyword, "gi");
#                 str = str.replace(regEx, function (a) {
#                     return '<span class="keysel">' + a + '</span>';
#                 });
#                 return str;
#             },
#
#             /**
#              * 검색 버튼 클릭 시
#              * @param e
#              */
#             clickSearch: function clickSearch(e) {
#                 if (!this.keyword || this.keyword.length === 0) {
#                     alert("검색어를 입력하세요");
#                     $("#keyword_str").focus();
#                     e.preventDefault();
#                 } else {
#                     location.href = "/search/search_list.html?keyword=" + this.keyword;
#                 }
#             },
#
#             /**
#              * 인기 검색어 클릭시
#              * @param book
#              */
#             clickPopularKeyword: function clickPopularKeyword(book) {
#                 var searchKeyword = book.bookName;
#                 location.href = "/search/search_list.html?keyword=" + searchKeyword;
#             },
#
#             /**
#              * 책 검색어 클릭시 책 상세로 이동
#              * @param book
#              */
#             clickBookKeyword: function clickBookKeyword(book) {
#                 location.href = "/store/books/look.php?p_code=" + book.link;
#             },
#
#             /**
#              * 교육 클릭시 교육 상세로 이동
#              * @param education
#              */
#             clickEducationKeyword: function clickEducationKeyword(education) {
#                 location.href = "/store/education/edu_view.html?p_code=" + education.link;
#             },
#
#             /**
#              * 컨텐츠 클릭시 컨텐츠 상세로 이동
#              * @param contents
#              */
#             clickContentKeyword: function clickContentKeyword(content) {
#                 location.href = "/channel/category/category_view.html?cms_code=" + content.link;
#             }
#         }
#     });
# </script>
# <!-- //메인 검색 및 카테고리 영역 -->
# <script language="JavaScript">
#
#   function Cart(strMode) {
#
#     var m_idx = "";
#     var p_code = "B5620881464";
#     var opt = $("input:radio[name=pay_choice]:checked").val();
#     var opt_size = $("input:radio[name=pay_choice]").size();
#     var ea = 1;
#
#     if(opt_size > 0 && typeof opt =="undefined") {
#       alert("상품을 선택해 주세요");
#       return;
#     }
#
#     if(typeof opt =="undefined") {
#       opt = p_code.substring(0,1);
#     }
#
#     $.ajax({
#       type : "post",
#       url : "/store/ajax.addCart.php",
#       data : { "p_code":p_code,"m_idx":m_idx,"ea":ea,"opt":opt},
#       dataType : "text",
#       success : function(result, status){
#         if(strMode=='cart') {
#           if(result ==1) {
#             $('#cartmsg').show();
#             $('#cartmsg2').hide();
#             add_cart_layer_open('layer_add_cart');
#           } else if(result==0) {
#             $('#cartmsg2').show();
#             $('#cartmsg').hide();
#             add_cart_layer_open('layer_add_cart');
#             return;
#           }
#         }  else {
#           location.href='/myhanbit/cart.html';
#         }
#       }
#     });
#   }
#
#   // 견본도서 장바구니 담기. by coffin. 2017-04-12
#   function Cart_p(strMode) {
#     var m_idx = "";
#     var p_code = "B5620881464";
#     var ea = 1;
#
#     if(typeof opt =="undefined") {
#       opt = p_code.substring(0,1);
#     }
#
#     $.ajax({
#       type : "post",
#       url : "/academy/professor/ajax.addCart.php",
#       data : { "p_code":p_code,"m_idx":m_idx,"ea":ea,"opt":opt},
#       dataType : "text",
#       success : function(result, status){
#         if(strMode == 'cart') {
#           location.href='/academy/professor/cart.html';
#         }  else {
#           location.href='/academy/professor/cart.html';
#         }
#       }
#     });
#   }
#
#   function Wishlist() {
#
#     var m_idx = "";
#     var p_code = "B5620881464";
#     var opt = $("input:radio[name=pay_choice]:checked").val();
#     var opt_size = $("input:radio[name=pay_choice]").size();
#     var ea = 1;
#     var comment = "";
#
#     if(m_idx =="") {
#       alert('로그인이 필요한 서비스 입니다.');
#       document.location.href='/member/login.html';
#       return;
#     }
#
#     if(opt_size > 0 && typeof opt =="undefined") {
#       alert("상품을 선택해 주세요");
#       return;
#     }
#
#     $.ajax({
#       type : "post",
#       url : "/store/ajax.addWishlist.php",
#       data : { "p_code":p_code,"m_idx":m_idx,"ea":ea,"opt":opt,"comment":comment},
#       dataType : "text",
#       success : function(result, status){
#         if(result ==1) {
#           alert("해당 상품을 위시리스트에 담았습니다");
#           return;
#         } else if(result==0) {
#           alert("이미 위시리스트에 추가된 상품입니다.");
#           return;
#         }
#       }
#     });
#   }
#
#   /*---------------------------------------------------------------
#     리뷰 SCRIPT
#   --------------------------------------------------------------- */
#   //리뷰 팝업요청 버튼
#   function review_start(){
#     var m_idx = '';
#     var re_chk_num = '0';
#
#     if(!m_idx) {
#       alert("로그인후 리뷰 등록이 가능합니다.");
#       document.location.href='/member/login.html';
#       return;
#     }
#
#     if(re_chk_num<1){
#       review_layer_open('layer_review');
#       $('#hbr_content_review').html('<textarea class="i_textarea" name="hbr_content" id="hbr_content" ></textarea>');
#       return;
#     }else{
#       alert('리뷰등록은 도서당 한번만 가능합니다.');
#       return;
#     }
#   }
#
#   //리뷰 등록 취소 버튼
#   function frm_reset(){
#     $('.review_layer').fadeOut();
#   }
#
#
#   //리뷰등록  처리 버튼
#   function review_proc(str,idx){
#
#     document.getElementById("hbr_content").value = myeditor.outputBodyHTML();
#
#     if(!$.trim($("#hbr_title").val()).length) {
#       alert("리뷰제목을 입력해주세요"); $("#hbr_title").focus();return;
#     }
#
#     if(!$.trim($("#hbr_score").val()).length) {
#       alert("별점 평가를 선택해주세요"); $("#hbr_score").focus();return;
#     }
#
#
#     if($("#hbr_content").val().length <= 13) {
#       alert("리뷰내용을 입력해주세요"); $("#hbr_content").focus();return;
#     }
#
#     var type_str      =  str;
#     var hbr_idx       =  idx;
#     var fk_p_code    = $("#fk_p_code").val();
#     var fk_m_idx      = $("#fk_m_idx").val();
#     var hbr_type     = $("#hbr_type").val();
#     var hbr_title      = $("#hbr_title").val();
#     var hbr_score    = $("#hbr_score").val();
#     var hbr_content   = $("#hbr_content").val();
#
#     var result_postdata= {
#         type_str    :   type_str,
#         hbr_idx      :  hbr_idx,
#         fk_p_code   :   fk_p_code,
#         fk_m_idx     :   fk_m_idx,
#         hbr_type     :  hbr_type,
#         hbr_title    :   hbr_title,
#         hbr_score   :   hbr_score,
#         hbr_content :   hbr_content
#     }
#     $.ajax({
#       type : "post",
#       url : "/store/ajax.addReview.php",
#       data:result_postdata,
#       contentType: "application/x-www-form-urlencoded; charset=UTF-8",
#       success : function(data){
#         if(data  >0){
#           $('.review_layer').fadeOut();
#           //location.reload();
#           var currentUrl = window.location.href.split('&');
#           //url "&" 있으면 삭제후 파라미터 추가
#           location.href = currentUrl[0]+'&tid=review';
#           //location.href='/store/books/look.php?p_code=B5620881464&tid=review';
#         }
#       }
#     });
#   }
#
#   //리뷰 수정, 삭제
#   function review_frm_proc(str,idx,n){
#
#     if(str =="redel"){
#       if(!confirm(" 삭제 후 데이터는 복구되지 않습니다. \n 해당 항목을 삭제 하시겠습니까? ")){ return; }
#     }
#     var result_postdata= {  str : str, idx:idx}
#     var result_url = "/inc/inc_store_layer_popup_review_ajax.php";
#
#     $.ajax({
#       type:"post",
#       url: result_url,
#       data:result_postdata,
#       contentType: "application/x-www-form-urlencoded; charset=UTF-8",
#       success: function(data){
#
#         if(str == "redel" && data ==1 ){
#           alert("리뷰가 삭제되었습니다.");
#           location.reload();
#           //location.href="/store/books/look.php?p_code=$p_code#review_tab";
#
#         }else{
#           $("#review_popup_div").html("");
#           $("#review_popup_div").html(data);
#           review_layer_open('layer_review');
#         }
#       }
#     });
#
#   }
#
#   //리뷰 댓글 리스트  ::  리뷰 idx , div_num
#   function comment_list(idx,n){
#     //alert(idx+"="+n)
#     var result_postdata= {  hbr_idx : idx, div_n:n}
#     var result_url = "/store/rev_comm_list.php";
#
#     $.ajax({
#       type:"post",
#       url: result_url,
#       data:result_postdata,
#       contentType: "application/x-www-form-urlencoded; charset=UTF-8",
#       success: function(data){
#         $("#comment_div_"+n).html(data);
#       }
#     });
#   }
#
#   //등록, 수정, 삭제    ::  처리 str , 리뷰 div_num , 리뷰 idx , 댓글 div_num,  댓글 idx
#   function comment_proc( str ,div_n, idx , div2_n ,re_idx){
#     var fk_hbr_idx     = idx;
#     var fk_m_idx     = $("#fk_m_idx").val();
#     var comment    = $("#comment_"+div_n).val();
#     var hbrc_idx     = re_idx;
#
#     if(!fk_m_idx) {
#       alert("로그인후 댓글을 작성 하실수있습니다.");
#       document.location.href='/member/login.html';
#       return;
#     }
#     if(str == "del"){
#       if(!confirm(" 삭제 후 데이터는 복구되지 않습니다. \n 해당 항목을 삭제 하시겠습니까? ")){ return; }
#     }else if(str == "ins"||str == "mod"){
#       if(!comment){
#         alert("내용을  입력해주세요.");
#         $("#comment_"+div_n).focus(); return;
#       }
#     }
#
#     var result_postdata= {
#       str:str,
#       div_n:div_n,
#       fk_hbr_idx : fk_hbr_idx,
#       fk_m_idx : fk_m_idx,
#       comment:comment,
#       hbrc_idx:hbrc_idx,
#       div2_n:div2_n
#     }
#     var result_url = "/store/rev_comm_proc.php";
#
#     $.ajax({
#       type:"post",
#       url: result_url,
#       data:result_postdata,
#       contentType: "application/x-www-form-urlencoded; charset=UTF-8",
#       success: function(data){
#         if(str == "mod_f"){
#           $("#re_"+div_n+"_"+div2_n).html("");
#           $("#re_"+div_n+"_"+div2_n).html(data);
#         }else{
#           //var ment = data.trim();
#           alert(data.trim());
#           comment_list( fk_hbr_idx,div_n); //댓글 리스트
#         }
#       }
#     });
#   }
#   /*---------------------------------------------------------------
#     리뷰 SCRIPT
#   --------------------------------------------------------------- */
#
#   /*---------------------------------------------------------------
#     오탈자 SCRIPT
#   --------------------------------------------------------------- */
#   //오탈자 리스트
#   function misprint_get_list(str){
#     var p_code     = 'B5620881464';
#     var conf      = $("#confirm_type option:selected").val();
#     var p_sort_type  = $("#p_sort_type").val();
#     var r_sort_type    = $("#r_sort_type").val();
#     if(!str)str = "page";
#
#     //정렬
#     if(str == "page"){
#       if( p_sort_type == "DE"){ p_sort_type = "A";
#       }else if( p_sort_type == "" ||  p_sort_type == "A"){  p_sort_type = "DE";
#       }
#       r_sort_type = "";
#     }
#     if(str == "regdt"){
#       if( r_sort_type == "DE"){ r_sort_type = "A";
#       }else if(  r_sort_type == "" ||r_sort_type == "A"){  r_sort_type = "DE";
#       }
#       p_sort_type = "";
#     }
#     $("#p_sort_type").val(p_sort_type);
#     $("#r_sort_type").val(r_sort_type);
#     //alert(p_sort_type+"=="+r_sort_type);
#
#     $.ajax({
#       type : "post",
#       url : "/inc/inc_store_detail_misprint_ajaxList.php",
#       data:{  fk_p_code:p_code , conf :conf , p_sort_type : p_sort_type , r_sort_type:r_sort_type },
#       contentType: "application/x-www-form-urlencoded; charset=UTF-8",
#       success : function(data){
#         $("#misprint_con_div").html("");
#         //$("#misprint_con_div").html(data);
#         $(".misprint_list").eq(0).html(data);
#         $(".misprint_list").eq(1).html(data);
#       }
#     });
#   }
#
#   //오탈자 팝업요청 버튼
#   function misprint_start(){
#     var m_idx = '';
#     if(!m_idx) {
#       alert("로그인 후 오탈자 등록이 가능합니다.");
#       document.location.href='/member/login.html';
#       return;
#     }
#     misprint_layer_open('layer_misprint');return;
#   }
#
#   //오탈자 등록 취소 버튼
#   function misprint_reset(){
#     $('.misprint_layer').fadeOut();
#   }
#
#   //오탈자등록  처리 버튼
#   function misprint_proc(str,idx){
#     var fk_m_idx        = $("#fk_m_idx").val();
#     if(!fk_m_idx) {
#       alert("로그인 후 사용이 가능합니다.");
#       document.location.href='/member/login.html';
#       return;
#     }
#
#     $("#err_info").val( myeditor_err.outputBodyHTML());
#
#     var type_str        =  str;
#     var fk_m_idx        = $("#fk_m_idx").val();
#     var fk_p_code      = $("#fk_p_code").val();
#     var err_type        = $("#err_type option:selected").val();
#     var err_p_version    = "";
#     var err_p_page      = $("#err_p_page").val();
#     var err_location    = $("#err_location").val();
#     var err_info        = $("#err_info").val();
#     var err_file        = $("#err_file").val();
#
#
#     if($("#err_type option:selected").val() =="") {
#       alert("구분을선택해주세요");$("#err_type").focus();return;
#     }
#
#     if($(":checkbox[name='err_p_version[]']:checked").length < 1) {
#       alert("상품버전을 선택해주세요");$("#err_p_version").focus();return;
#     }
#
#     if(!err_p_page) {
#       alert("페이지를 입력해주세요");$("#err_p_page").focus();return;
#     }
#
#     if(!err_location) {
#       alert("위치정보를 입력해주세요");$("#err_location").focus();return;
#     }
#
#     var err_info_len = $("#err_info").val().length;
#     if(err_info_len <20) {
#       alert("내용을 입력해주세요");$("#err_info").focus();return;
#     }
#
#     err_p_version = "";
#     $('input:checkbox[name="err_p_version[]"]').each(function() {
#       if(this.checked){
#         err_p_version+=','+$(this).val();
#       }
#      });
#     err_p_version = err_p_version.substring(1,err_p_version.length);
#
#     var result_postdata= {
#          type_str        :  type_str,
#          fk_m_idx        :  fk_m_idx,
#          fk_p_code      :   fk_p_code,
#          err_type        :  err_type,
#          err_p_version    :  err_p_version,
#          err_p_page      :   err_p_page,
#          err_location      :  err_location,
#          err_info        :  err_info,
#          err_file          :  err_file
#     }
#     $.ajax({
#       type : "post",
#       url : "/store/ajax.addMisprint.php",
#       data:result_postdata,
#       contentType: "application/x-www-form-urlencoded; charset=UTF-8",
#       success : function(data){
#         if(data  >0){
#           $('.misprint_layer').fadeOut();
#           var currentUrl = window.location.href.split('&');
#
#           //url "&" 있으면 삭제후 파라미터 추가
#           location.href = currentUrl[0]+'&tid=misprint';
#           //location.href='/store/books/look.php?p_code=B5620881464&tid=misprint';
#           //location.reload(true);
#         }
#       }
#     });
#   }
#
#   //오탈자 인쇄하기
#   function misprint_print(){
#     var p_code       = 'B5620881464';
#     var conf        = $("#confirm_type option:selected").val();
#     var p_sort_type  = $("#p_sort_type").val();
#     var r_sort_type    = $("#r_sort_type").val();
#
#     //var sort_type;
#     //if(p_sort_type)sort_type = p_sort_type ;
#     //if(r_sort_type)sort_type = r_sort_type ;
#
#     var url_full = "/store/books/misprint_view.html?fk_p_code="+p_code+"&conf="+conf+"&p_sort_type="+p_sort_type+"&r_sort_type="+r_sort_type;
#
#     var openNewWindow = window.open("about:blank");
#         openNewWindow.location.href = url_full;
#   }
#
#   /*---------------------------------------------------------------
#     오탈자 SCRIPT
#   --------------------------------------------------------------- */
#
#   /*---------------------------------------------------------------
#     도서인증 SCRIPT
#   --------------------------------------------------------------- */
#   function book_auth(){
#     var fk_m_idx        = $("#fk_m_idx").val();
#     if(!fk_m_idx) {
#       alert("로그인 후 사용이 가능합니다.");
#       document.location.href='/member/login.html';
#       return;
#     }
#
#     var fk_m_idx      = $("#fk_m_idx").val();
#     var fk_p_code      = $("#fk_p_code").val();
#     var buy_date      = $("#buy_date").val();
#     var buy_site        = $("#buy_site").val();
#     var add_code      = $("#add_code").val();
#
#     if(!buy_site) {
#       alert("구입처를 선택해주세요");$("#buy_site").focus();return;
#     }
#
#     if(!buy_date) {
#       alert("구입일을 입력해주세요");$("#buy_date").focus();return;
#     }
#
#     if(!add_code) {
#       alert("부가기호를 입력해주세요");$("#add_code").focus();return;
#     }
#
#     $("#cfrm").submit();
#
#   }
#   /*---------------------------------------------------------------
#     도서인증 SCRIPT
#   --------------------------------------------------------------- */
#
# </script>
# <!-- Contents -->
# <div id="container">
# <!-- 상단 광고 배너 -->
# <!--<div class="docu_title" style="margin-top:4px;text-align:center;padding:4px;font-weight:bold;background-color:#003475;border:2px solid #ffffff;">
# <a href="/event/current/current_event_view.html?hbe_idx=177" alt="회원정보 업데이트 이벤트" class="hvr-glow" style="width:100%;padding:4px;color:#fff;letter-spacing:-1px;">오래된 내 정보 속 옥의 티를 찾아라(2022.9.22~12.31) / 회원정보 UPDATE하고 선물도 받고!</a>
# </div>--> <!-- //상단 광고 배너 -->
# <!-- 카테고리 상세 wrap -->
# <div class="store_view_wrap">
# <div class="store_view_wrap_l">
# <!-- 책 정보 -->
# <div class="store_view_area">
# <div class="store_product_box">
# <div class="store_product_box_img">
# <img alt="STEM CookBook, 전기 및 하이브리드 자동차(3판)" class="thumb" src="/data/books/B5620881464_l.jpg">
# </img></div>
# <div class="store_product_box_btn"><a href="javascript:;" onclick="javascript:openPreviewFlip('https://preview2.hanbit.co.kr/books/ddgw/','PREVIEW');return false;">미리보기</a></div>
# </div>
# <div class="store_product_info_box">
# <h3>STEM CookBook, 전기 및 하이브리드 자동차(3판)</h3>
# <p class="stit"></p>
# <div class="info_area">
# <div class="info_ico">
# <p class="ico_a">한빛아카데미</p>
# <p class="ico_book2">번역서</p>
# <p class="ico_shopping1">판매중</p>
# </div>
# <div class="sns_ico">
# <span class="ico_facebook"><a href="https://www.facebook.com/share.php?u=https://www.hanbit.co.kr/academy/books/book_view.html?p_code=B5620881464" target="_blank">페이스북 퍼가기</a></span>
# <!-- <span class="ico_google"><a href="https://plus.google.com/share?url=https://www.hanbit.co.kr/academy/books/book_view.html?p_code=B5620881464" target="_blank">구글+ 퍼가기</a></span> -->
# <span class="ico_twitter"><a href="https://twitter.com/share?text=STEM+CookBook%2C+%EC%A0%84%EA%B8%B0+%EB%B0%8F+%ED%95%98%EC%9D%B4%EB%B8%8C%EB%A6%AC%EB%93%9C+%EC%9E%90%EB%8F%99%EC%B0%A8%26%2340%3B3%ED%8C%90%26%2341%3B&amp;url=https://www.hanbit.co.kr/academy/books/book_view.html?p_code=B5620881464" target="_blank">트위터 퍼가기</a></span>
# </div>
# </div>
# <ul class="info_list">
# <li><strong>저자 : </strong><span>Iqbal Husain </span></li>
# <li><strong>번역 : </strong><span>임원식 , 김정윤 , 김기찬 , 강동우 </span></li>
# <li><strong>출간 : </strong><span>2023-01-10</span></li>
# <li><strong>페이지 : </strong><span>592 쪽</span></li>
# <li><strong>ISBN : </strong><span>9791156646372</span></li>
# <li><strong>물류코드 :</strong><span>4637</span></li>
# </ul>
# <div style="border:1px solid #dddddd;background-color:#f9f9f9;line-height:130%;padding:6px;margin-bottom:10px;color:#a01025;font-size:12px;letter-spacing:-1px;">
#                         본 도서는 대학 강의용 교재로 개발되었으므로 연습문제 해답은 제공하지 않습니다.
#                     </div>
# <div class="tag_area"><span>TAG : </span><a href="/search/search_list.html?ptype=B&amp;keyword=전기자동차">전기자동차</a> ,<a href="/search/search_list.html?ptype=B&amp;keyword=하이브리드 자동차">하이브리드 자동차</a> ,<a href="/search/search_list.html?ptype=B&amp;keyword=친환경자동차">친환경자동차</a> ,<a href="/search/search_list.html?ptype=B&amp;keyword=EV">EV</a> ,<a href="/search/search_list.html?ptype=B&amp;keyword=HEV">HEV</a> ,<a href="/search/search_list.html?ptype=B&amp;keyword=ICEV">ICEV</a> ,<a href="/search/search_list.html?ptype=B&amp;keyword=모터">모터</a> ,<a href="/search/search_list.html?ptype=B&amp;keyword=발전기">발전기</a> ,<a href="/search/search_list.html?ptype=B&amp;keyword=배터리">배터리</a> ,<a href="/search/search_list.html?ptype=B&amp;keyword=전기 기계">전기 기계</a> </div>
# <div class="step_area ico_step2">
# <span> 초급 </span>
# <span><strong>초중급</strong></span>
# <span> 중급 </span>
# <span> 중고급 </span>
# <span> 고급 </span>
# </div>
# </div>
# </div>
# <!-- //책 정보 -->
# <!-- 별점 및 좋아요 -->
# <script>
#
# 			$(function() {
# 				$('.store_grade_star').raty({
# 					readOnly: true,
# 					score: 0,
# 					starHalf   : '/academy/images/star_l-half.png',
# 					starOff    : '/academy/images/star_l-off.png',
# 					starOn     : '/academy/images/star_l-on.png'
# 				});
#
# 			});
# 			</script>
# <div class="store_like_area">
# <div class="store_grade"><div class="store_grade_star"></div><span>0점 (0명)</span></div>
# <div class="store_like"><span>좋아요 : </span><font id="likescore">0</font></div>
# </div> <!-- //별점 및 좋아요 -->
# <!-- 버튼 -->
# <div class="store_btn_area">
# <div class="btn_review"><a href="javascript:;" onclick="review_start()">리뷰쓰기</a></div>
# <div class="btn_like"><a href="javascript:setLike('B5620881464','');">좋아요</a></div>
# <div class="btn_misprint"><a href="javascript:;" onclick="misprint_start()">오탈자 등록</a></div>
# <div class="btn_certification"><a href="javascript:alert('로그인 후 이용가능한 서비스입니다.');">도서인증</a></div>
# </div>
# <!-- //버튼 -->
# <!-- 하단 컨텐츠 -->
# <div class="store_detail_area">
# <!-- 텝메뉴 -->
# <script>
#         $(function() {
#           $( ".detial_tabs" ).tabs();
#         });
# ...
# </li>
# <li class="obuy">
# <div class="obuy_wrap">
# <a href="https://www.aladin.co.kr/shop/wproduct.aspx?ItemId=308797390" target="_blank">알라딘</a>
# </div>
# <span><a href="https://www.aladin.co.kr/shop/wproduct.aspx?ItemId=308797390" target="_blank"><img alt="구매" class="btn" height="18" src="/images/common/btn_obuy.gif" title="구매 새창" width="29"/></a></span>
# </li>
# <li class="obuy">
# <div class="obuy_wrap">
# <a href="http://book.interpark.com/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356424829&amp;sc.saNo=003002001&amp;bid1=search&amp;bid2=product&amp;bid3=title&amp;bid4=001" target="_blank">인터파크 도서</a>
# </div>
# <span><a href="http://book.interpark.com/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356424829&amp;sc.saNo=003002001&amp;bid1=search&amp;bid2=product&amp;bid3=title&amp;bid4=001" target="_blank"><img alt="구매" class="btn" height="18" src="/images/common/btn_obuy.gif" title="구매 새창" width="29"/></a></span>
# </li>
# </ul>
# <!-- //결재 정보 -->
# <!-- 관련 사이트 -->
# <!-- //관련 사이트 -->
# </div>
# </div>
# <!-- //카테고리 상세 wrap -->
# <!-- 레이어 팝업 - 리뷰쓰기 -->
# <div id="review_popup_div">
# <div class="review_layer">
# <div class="bg"></div>
# <div class="review_pop-layer" id="layer_review">
# <div class="pop-container">
# <div class="pop-conts">
# <!--content //-->
# <form enctype="multipart/form-data" id="frm" method="post" name="frm">
# <input id="fk_p_code" name="fk_p_code" type="hidden" value="B5620881464"/>
# <input id="fk_m_idx" name="fk_m_idx" type="hidden" value=""/>
# <input id="hbr_score" name="hbr_score" type="hidden" value=""/>
# <p class="tit">리뷰쓰기</p>
# <div class="close"><a class="cbtn" href="javascript:;" onclick=""><img alt="닫기" height="38" src="https://www.hanbit.co.kr/images/common/icon_close2.png" width="39"/></a></div>
# <div class="layer_scroll">
# <div class="layer_con_box">
# <fieldset>
# <div class="lp_register_li">
# <div class="i_tit"><span>* </span>도서명 :</div>
# <div class="i_con">
# 										STEM CookBook, 전기 및 하이브리드 자동차(3판)									</div>
# </div>
# <div class="lp_register_li">
# <div class="i_tit"><span>* </span>제목 :</div>
# <div class="i_con">
# <label>
# <input class="i_text1" id="hbr_title" name="hbr_title" type="text" value=""/>
# </label>
# </div>
# </div>
# <div class="lp_register_li">
# <div class="i_tit"><span>* </span>별점평가</div>
# <div class="i_con">
# <script>
# 										$.fn.raty.defaults.path = "https://www.hanbit.co.kr";
# 										$(function() {
# 											$('#default').raty({
# 												click: function(score, evt) { $("#hbr_score").val(score);}
# 											});
# 										});
# 										</script>
# <div id="default" style="margin-top:5px;"></div>
# <div class="highlight"><pre><span class="nt"><div></div></span></pre></div>
# </div>
# </div>
# <div class="lp_register_li">
# <div class="i_tit"><span>* </span>내용 :</div>
# <div class="i_con" id="hbc_cont_div">
# <label>
# <textarea class="i_textarea" id="hbr_content" name="hbr_content"></textarea>
# <script type="text/javascript">
# 											var myeditor = new cheditor(); // 에디터 개체를 생성합니다.
# 											myeditor.config.editorHeight = '200px'; // 에디터 세로폭입니다.
# 											myeditor.config.editorWidth = '800px'; // 에디터 가로폭입니다.
# 											myeditor.inputForm = 'hbr_content'; // textarea의 id 이름입니다. 주의: name 속성 이름이 아닙니다.
# 											myeditor.useBold = false;
# 											myeditor.run(); // 에디터를 실행합니다.
# 											</script>
# </label>
# </div>
# </div>
# </fieldset>
# </div>
# <p class="note_tit">* 리뷰 작성시 유의사항</p>
# <p class="note_txt">글이나 이미지/사진 저작권 등 다른 사람의 권리를 침해하거나 명예를 훼손하는 게시물은 이용약관 및 관련법률에 의해 제재를 받을 수 있습니다.</p>
# <p class="note_txt">
# 								1. 특히 뉴스/언론사 기사를 전문 또는 부분적으로 '허락없이' 갖고 와서는 안됩니다 (출처를 밝히는 경우에도 안됨).<br/>
# 								2. 저작권자의 허락을 받지 않은 콘텐츠의 무단 사용은 저작권자의 권리를 침해하는 행위로, 이에 대한 법적 책임을 지게 될 수 있습니다.
# 							</p>
# <div class="btn_layer_default">
# <label><button class="btn_blue" id="proc_btn" name="proc_btn" onclick="review_proc('re_ins','');" type="button" value="">등록</button></label>
# <label><button class="btn_white" id="reset_btn" name="reset_btn" onclick="frm_reset();" type="button" value="">취소</button></label>
# </div>
# </div>
# </form>
# <!--// content-->
# </div>
# </div>
# </div>
# </div>
# </div> <!-- //레이어 팝업 - 리뷰쓰기 -->
# <!-- 레이어 팝업 - 오탈자등록 -->
# <div class="misprint_layer">
# <div class="bg"></div>
# <div class="misprint_pop-layer" id="layer_misprint">
# <div class="pop-container">
# <div class="pop-conts">
# <!--content //-->
# <p class="tit">오탈자 등록</p>
# <div class="close"><a class="cbtn" href="javascript:;" onclick=""><img alt="닫기" height="38" src="/images/common/icon_close2.png" width="39"/></a></div>
# <div class="layer_scroll">
# <form enctype="multipart/form-data" id="err_input_frm" method="post" name="err_input_frm">
# <input id="fk_p_code" name="fk_p_code" type="hidden" value="B5620881464"/>
# <input id="fk_isbn" name="fk_isbn" type="hidden" value=""/>
# <input id="fk_m_idx" name="fk_m_idx" type="hidden" value=""/>
# <div class="layer_con_box">
# <fieldset>
# <div class="lp_register_li">
# <div class="i_tit"><span>* </span>도서명 :</div>
# <div class="i_con">
# 										STEM CookBook, 전기 및 하이브리드 자동차(3판)									</div>
# </div>
# <div class="lp_register_li">
# <div class="i_tit"><span>* </span>구분 :</div>
# <div class="i_con">
# <label>
# <select class="i_select" id="err_type" name="err_type">
# <option selected="" value="">오탈자 유형 선택</option>
# <option value="G">내용 오류/확인 요청</option>
# <option value="P">주요 기술 오류(로직/코드)</option>
# <option value="E">오자/탈자, 띄어쓰기 오류</option>
# </select>
# </label>
# </div>
# </div>
# <div class="lp_register_li">
# <div class="i_tit"><span>* </span>상품 버전</div>
# <div class="i_con">
# <span class="chk_list"><input class="i_check" name="err_p_version[]" type="checkbox" value="종이책"/><span>종이책</span></span>
# <span class="chk_list"><input class="i_check" name="err_p_version[]" type="checkbox" value="PDF"/><span>PDF</span></span>
# <span class="chk_list"><input class="i_check" name="err_p_version[]" type="checkbox" value="ePub"/><span>ePub</span></span>
# <!--<span class="chk_list"><input type="checkbox" name="err_p_version[]" class="i_check" value="Mobi"><span>Mobi</span></span>-->
# </div>
# </div>
# <div class="lp_register_li">
# <div class="i_tit"><span>* </span>페이지 :</div>
# <div class="i_con">
# <label>
# <input class="i_text2" id="err_p_page" name="err_p_page" onkeyup="this.value=number_filter(this.value);" type="text"/><span>숫자로만 입력해주세요.</span>
# </label>
# </div>
# </div>
# <div class="lp_register_li">
# <div class="i_tit"><span>* </span>위치정보 :</div>
# <div class="i_con">
# <label>
# <input class="i_text1" id="err_location" name="err_location" type="text"/>
# </label>
# </div>
# </div>
# <div class="lp_register_li">
# <div class="i_tit"><span>* </span>내용 :</div>
# <div class="i_con">
# <label>
# <textarea class="i_textarea" id="err_info" name="err_info"></textarea>
# <script type="text/javascript">
# 											var myeditor_err = new cheditor(); // 에디터 개체를 생성합니다.
# 											myeditor_err.config.editorHeight = '200px'; // 에디터 세로폭입니다.
# 											myeditor_err.config.editorWidth = '800px'; // 에디터 가로폭입니다.
# 											myeditor_err.inputForm = 'err_info'; // textarea의 id 이름입니다. 주의: name 속성 이름이 아닙니다.
# 											myeditor_err.useBold = false;
# 											myeditor_err.run(); // 에디터를 실행합니다.
# 											</script>
# </label>
# </div>
# </div>
# </fieldset>
# </div>
# </form>
# <div class="btn_layer_default">
# <label>
# <button class="btn_blue" name="" onclick="misprint_proc('ins','');" type="submit" value="">등록</button>
# </label>
# <label>
# <button class="btn_white" name="" onclick="misprint_reset();" type="submit" value="">취소</button>
# </label>
# </div>
# </div>
# <!--// content-->
# </div>
# </div>
# </div>
# </div>
# <!-- //레이어 팝업 - 오탈자등록 -->
# <!-- 레이어 팝업 - 도서인증 -->
# <link href="/css/jquery-ui.css" rel="stylesheet"/>
# <script src="/js/jquery.ui.datepicker-ko.js" type="text/javascript"></script>
# <script type="text/javascript">
#  $(function() {
#   $("#buy_date").datepicker({ maxDate: '0'  });
#  });
#
# </script>
# <form action="/store/ajax.addBookauth.php" id="cfrm" method="post" name="cfrm">
# <input id="fk_p_code" name="fk_p_code" type="hidden" value="B5620881464"/>
# <input id="fk_m_idx" name="fk_m_idx" type="hidden" value=""/>
# <div class="certification_layer">
# <div class="bg"></div>
# <div class="certification_pop-layer" id="layer_certification">
# <div class="pop-container">
# <div class="pop-conts">
# <!--content //-->
# <p class="tit">도서 인증</p>
# <div class="close"><a class="cbtn" href="javascript:;" onclick=""><img alt="닫기" height="38" src="https://www.hanbit.co.kr/images/common/icon_close2.png" width="39"/></a></div>
# <div class="layer_scroll">
# <div class="layer_con_box">
# <fieldset>
# <div class="lp_register_li">
# <div class="i_tit">도서명<span>* </span></div>
# <div class="i_con">STEM CookBook, 전기 및 하이브리드 자동차(3판)</div>
# </div>
# <div class="lp_register_li">
# <div class="i_tit">구입처<span>* </span></div>
# <div class="i_con">
# <label>
# <select class="i_select" id="buy_site" name="buy_site">
# <option selected="" value="">선택하세요.</option>
# <option value="교보문고">교보문고</option>
# <option value="예스24">예스24</option>
# <option value="알라딘">알라딘</option>
# <!--                       <option value="반디앤루니스">반디앤루니스</option> -->
# <option value="영풍문고">영풍문고</option>
# <option value="인터파크">인터파크</option>
# <option value="쿠팡">쿠팡</option>
# <!--                       <option value="한빛 웹사이트">한빛 웹사이트</option> -->
# <option value="지역서점">지역서점</option>
# </select>
# </label>
# </div>
# </div>
# <div class="lp_register_li">
# <div class="i_tit">구입일<span>* </span></div>
# <div class="i_con">
# <!-- 달력 -->
# <label><input class="i_text2" id="buy_date" name="buy_date" type="text" value=""/></label>
# <label><button class="i_car" id="btnBuyDate" name="btnBuyDate" type="button" value="검색">달력</button></label>
# <!-- //달력 -->
# </div>
# </div>
# <div class="lp_register_li">
# <div class="i_tit">부가기호<span>* </span></div>
# <div class="i_con">
# <label>
# <input class="i_text2" id="add_code" name="add_code" type="text"/>
# </label>
# </div>
# </div>
# <div class="barcode_img">
# <img alt="부가기호 안내" src="https://www.hanbit.co.kr/images/common/rs_barcode_ban.png">
# </img></div>
# </fieldset>
# </div>
# <p class="txt">* 온라인 또는 오프라인 서점에서 구입한 도서를 인증하면 마일리지 500점을 드립니다.</p>
# <p class="txt">* 도서인증은 일 3권, 월 10권, 년 50권으로 제한되며 절판도서, eBook 등 일부 도서는 인증이 제한됩니다.</p>
# <p class="txt">* 구입하지 않고, 허위로 도서 인증을 한 것으로 판단되면 웹사이트 이용이 제한될 수 있습니다.</p>
# <div class="btn_layer_default">
# <label>
# <button class="btn_blue" name="btnBookauth1" onclick="book_auth();" type="button">등록</button>
# </label>
# <label>
# <button class="btn_white" name="btnBookauth2" type="button" value="">취소</button>
# </label>
# </div>
# </div>
# <!--// content-->
# </div>
# </div>
# </div>
# </div>
# </form>
# <script language="JavaScript">
# <!--
#   $("#btnBuyDate").click(function() {
#     $('#buy_date').datepicker('show');
#   });
#
# //-->
# </script> <!-- //레이어 팝업 - 도서인증 -->
# <!-- 레이어 팝업 - 카트 담기 -->
# <div class="add_cart_layer">
# <div class="bg"></div>
# <div class="add_cart_pop-layer" id="layer_add_cart">
# <div class="pop-container">
# <div class="pop-conts">
# <!--content //-->
# <div class="close"><a class="cbtn" href="javascript:;" onclick=""><img alt="닫기" height="38" src="https://www.hanbit.co.kr/images/common/icon_close.png" width="38"/></a></div>
# <p class="ctxt"><span id="cartmsg">해당 상품을 장바구니에 담았습니다.</span><span id="cartmsg2">이미 장바구니에 추가된 상품입니다.</span><br/>장바구니로 이동하시겠습니까?</p>
# <div class="btn_layer">
# <a href="/myhanbit/cart.html">장바구니<br/>이동</a>
# <!--<a href="javascript:;" onClick="$('.add_cart_layer').hide();">쇼핑<br />계속</a>-->
# <a class="cbtn" href="javascript:;" onclick="">쇼핑<br/>계속</a>
# </div>
# <!--// content-->
# </div>
# </div>
# </div>
# </div> <!-- //레이어 팝업 - 카트 담기 -->
# </div>
# <!-- //Contents -->
# <script>
#
# //숫자만 입력
# function number_filter(str_value){
#   return str_value.replace(/[^0-9]/gi, "");
# }
#
# function hb_show_tabs(t_num){
#   //alert(t_num);
#   var t_max = 9;
#   for(var t=1; t <t_max; t++){
#     if(t_num ==0){
#       $("#tabs_"+t).show();
#       $(".detail_tit").css({"display":"block"});
#     }else{
#       if(t==t_num){
#         $("#tabs_"+t).show();
#         $(".detail_tit").css({"display":"none"});
#       }else{
#         $("#tabs_"+t).hide();
#       }
#     }
#   }
#
# }
#
# var tid= "";
# if(tid=="review"){
#   hb_show_tabs(5);
#   document.getElementById("review_tab").scrollIntoView();
#
# }else if(tid=="misprint"){
#   hb_show_tabs(6);
#   document.getElementById("misprint_tab").scrollIntoView();
#
# }else if(tid=="exam"){
#   hb_show_tabs(7);
#   document.getElementById("exam_tab").scrollIntoView();
#
# }else{
#   hb_show_tabs(0);
# }
#
# //해쉬 태그로 포커스 이동후 해쉬 제거
# function removeHash () {
#     var scrollV, scrollH, loc = window.location;
#     if ("pushState" in history)
#         history.pushState("", document.title, loc.pathname + loc.search);
#     else {
#         // Prevent scrolling by storing the page's current scroll offset
#         scrollV = document.body.scrollTop;
#         scrollH = document.body.scrollLeft;
#
#         loc.hash = "";
#
#         // Restore the scroll offset, should be flicker free
#         document.body.scrollTop = scrollV;
#         document.body.scrollLeft = scrollH;
#     }
# }
# </script>
# <!-- Footer -->
# <footer>
# <!-- 공지사항 -->
# <div class="foot_notice">
# <span>
# <a href="https://www.hanbit.co.kr/support/notice_list.html"><strong>공지사항</strong></a> &gt;
#     </span>
# <a href="/support/notice_view.html?hnb_idx=324">설 연휴로 인한 배송 안내(1월 18일 오전 12시 택배마감/1월 25일 택배재개)</a>
# </div>
# <!-- //공지사항 -->
# <div class="foot_contents">
# <!-- 하단 메뉴 -->
# <div class="foot_menu">
# <!-- added by coffin -->
# <ul>
# <li><a href="https://www.hanbit.co.kr/publisher/index.html" target="_blank">회사소개</a>(<a href="https://www.hanbit.co.kr/publisher/index.html" target="_blank">KOR</a> | <a href="https://www.hanbit.co.kr/publisher/index.html?lang=e" target="_blank">ENG</a>) • <a href="https://www.hanbit.co.kr/publisher/contact.html?lang=k" target="_blank">약도</a></li>
# <li><a href="https://www.hanbit.co.kr/publisher/write.html" target="_blank">기획 및 원고 모집</a></li>
# <li><a href="https://www.hanbit.co.kr/publisher/career.html" target="_blank">채용</a> • 입사지원 <a href="mailto:jobs@hanbit.co.kr">jobs@hanbit.co.kr</a></li>
# <li><a href="https://www.hanbit.co.kr/publisher/foreignrights.html" target="_blank">FOREIGN RIGHTS</a></li>
# <li><a href="https://www.hanbit.co.kr/member/use_agreement.html">이용약관</a> • <a href="https://www.hanbit.co.kr/member/privacy_policy.html"><strong>개인정보처리방침</strong></a></li>
# <li><a href="https://www.hanbit.co.kr/sitemap/sitemap.html">사이트맵</a></li>
# </ul>
# </div>
# <!-- //하단 메뉴 -->
# <!-- SNS -->
# <div class="foot_sns">
# <ul>
# <li class="foot_facebook"><a href="https://www.facebook.com/hanbitacademy/" target="_blank"><span>페이스북</span></a></li>
# <li class="foot_youtube"><a href="https://www.youtube.com/channel/UCHfxmM0R8HZDJQoBOFkpDKA" target="_blank"><span>유튜브</span></a></li>
# </ul>
# <fieldset class="foot_srch">
# <legend>하단 검색영역</legend>
# <input accesskey="s" class="foot_srch_keyword" id="foot_keyword_str" style="font-size:16px;" title="검색어" type="text" value=""/>
# <input alt="" class="foot_srch_btn" onclick="foot_sch_smit();" style="cursor: pointer;" type="button"/>
# </fieldset>
# <script>
#         $(document).ready(function() {
#           $('#foot_keyword_str').keyup(function(e) {
#             if (e.keyCode == 13)
#               foot_sch_smit();
#           });
#         });
#
#         function foot_sch_smit(){
#           var foot_keyword_str = $("#foot_keyword_str").val();
#           var searchUrl = "/search/search_list.html?keyword="+foot_keyword_str;
#
#           if(!foot_keyword_str){
#             alert("검색어를 입력해주세요");
#             $("#foot_keyword_str").focus();
#           }else{
#             location.href = searchUrl;
#           }
#         }
#       </script>
# </div>
# <!-- //SNS -->
# <!-- 한빛 정보 -->
# <div class="foot_about">
# <div class="foot_about_area">
# <p>한빛아카데미㈜</p>
# <p>(03785) 서울 서대문구 연희로2길 62 2층</p>
# <p>TEL : 02-336-7112 / FAX : 02-336-7199</p>
# <p>대표이사 : 전태호</p>
# <p>사업자등록번호 : 105-87-81648</p>
# </div>
# </div>
# <!-- //한빛 정보 -->
# </div>
# <div class="copyright">©1993-2023 Hanbit Publishing Network, Inc. All rights reserved.</div>
# </footer>
# <!-- //푸터 -->
# <div class="foot_download_btn"><a href="https://www.hanbit.co.kr/support/supplement_list.html">자료실</a></div>
# <!-- 공통 JS 호출 -->
# <script src="/js/common.js" type="text/javascript"></script>
# <!-- //공통 JS 호출 -->
# </body>
# </html>

# %%
# title
title = sub_soup.select_one('.store_product_info_box > h3').text.strip()
title
# Out:
# 'STEM CookBook, 전기 및 하이브리드 자동차(3판)'

# %%
info_list = sub_soup.select('.info_list > li')
info_list
# Out:
# [<li><strong>저자 : </strong><span>Iqbal Husain </span></li>,
#  <li><strong>번역 : </strong><span>임원식 , 김정윤 , 김기찬 , 강동우 </span></li>,
#  <li><strong>출간 : </strong><span>2023-01-10</span></li>,
#  <li><strong>페이지 : </strong><span>592 쪽</span></li>,
#  <li><strong>ISBN : </strong><span>9791156646372</span></li>,
#  <li><strong>물류코드 :</strong><span>4637</span></li>]

# %%
info_dict = {}
for li in info_list:
    key = li.find('strong').text.split(' ')[0]
    value = li.find('span').text.strip()
    info_dict[key] = value
info_dict
# Out:
# {'저자': 'Iqbal Husain',
#  '번역': '임원식 , 김정윤 , 김기찬 , 강동우',
#  '출간': '2023-01-10',
#  '페이지': '592 쪽',
#  'ISBN': '9791156646372',
#  '물류코드': '4637'}

# %%
author = info_dict['저자']
translator = info_dict['번역']
date = info_dict['출간']
page = info_dict['페이지']

author, translator, date, page
# Out:
# ('Iqbal Husain', '임원식 , 김정윤 , 김기찬 , 강동우', '2023-01-10', '592 쪽')

# %%
## 번역이 없는 경우
try:
    translator = info_dict['번역']
except:
    translator = '-'

# %% [markdown]
# # 2. 한 페이지 정보 가져오기

# %%
lines=[]
for li in lis:
    href = li.find('a')['href']
    sub_req = requests.get(base_url + href)
    sub_soup = BeautifulSoup(sub_req.text, 'html.parser')
    
    title = sub_soup.select_one('.store_product_info_box > h3').text.strip()
    
    info_list = sub_soup.select('.info_list > li')
    info_dict = {}
    for li in info_list:
        key = li.find('strong').text.split(' ')[0]
        value = li.find('span').text.strip()
        info_dict[key] = value
        info_dict
    
    author = info_dict['저자']
    try:
        translator = info_dict['번역']
    except:
        translator = '-'
    date = info_dict['출간']
    page = int(info_dict['페이지'].split(' ')[0].replace(',', ''))
    price = int(sub_soup.select_one('.pbr > strong').text.replace(',',''))
    lines.append({'제목' : title, '저자' : author, '번역' : translator, '출간일' : date, '쪽수' : page, '판매가' : price})

# %%
lines
# Out:
# [{'제목': 'STEM CookBook, 전기 및 하이브리드 자동차(3판)',
#   '저자': 'Iqbal Husain',
#   '번역': '임원식 , 김정윤 , 김기찬 , 강동우',
#   '출간일': '2023-01-10',
#   '쪽수': 592,
#   '판매가': 35000},
#  {'제목': 'IT CookBook, 컴퓨터 비전과 딥러닝',
#   '저자': '오일석',
#   '번역': '-',
#   '출간일': '2023-01-05',
#   '쪽수': 664,
#   '판매가': 39000},
#  {'제목': '리더십 : 이론과 실제 (9판)',
#   '저자': 'Peter G. Northouse',
#   '번역': '김남현',
#   '출간일': '2023-01-02',
#   '쪽수': 660,
#   '판매가': 36000},
#  {'제목': 'IT CookBook, JAVA 마스터',
#   '저자': '송미영',
#   '번역': '-',
#   '출간일': '2023-01-01',
#   '쪽수': 732,
#   '판매가': 30000},
#  {'제목': 'IT CookBook, 데이터 과학을 위한 파이썬 프로그래밍(2판)',
#   '저자': '최성철',
#   '번역': '-',
#   '출간일': '2023-01-01',
#   '쪽수': 540,
#   '판매가': 30000},
#  {'제목': 'IT CookBook, 생활 속 예제로 배우는 생생 데이터 분석',
#   '저자': '조인석',
#   '번역': '-',
#   '출간일': '2023-01-01',
#   '쪽수': 428,
#   '판매가': 23000},
#  {'제목': 'IT CookBook, 파워포인트 2019',
#   '저자': '김지연',
#   '번역': '-',
#   '출간일': '2023-01-01',
#   '쪽수': 440,
#   '판매가': 20000},
#  {'제목': '메타버스로 구현하는 나만의 세상',
#   '저자': '한규정 , 최종원 , 강신조 , 심민정 , 안형준 , 위새람 , 최동일',
#   '번역': '-',
#   '출간일': '2023-01-01',
#   '쪽수': 388,
#   '판매가': 23000},
#  {'제목': '국제경영학 : 환경과 운영 (17판)',
#   '저자': 'John D. Daniels , Lee H. Radebaugh , Daniel P. Sullivan , Reid W. Click',
#   '번역': '문정빈 , 김태중 , 노태우 , 정선욱 , 편주현',
#   '출간일': '2022-12-30',
#   '쪽수': 716,
#   '판매가': 41000},
#  {'제목': '머신러닝을 위한 수학',
#   '저자': '이병준',
#   '번역': '-',
#   '출간일': '2022-12-26',
#   '쪽수': 344,
#   '판매가': 28000},
#  {'제목': '위상수학 첫걸음',
#   '저자': 'Fred H. Croom',
#   '번역': '한빛수학교재연구소 , 김상현(감수)',
#   '출간일': '2022-12-26',
#   '쪽수': 380,
#   '판매가': 29000},
#  {'제목': 'IT CookBook, 전자기학 : ELECTROMAGNETICS (2판)',
#   '저자': 'Arlon T. Adams , Jay Kyoon Lee(이재균) , Jay Kyoon Lee  - 감수',
#   '번역': '유태훈',
#   '출간일': '2022-12-25',
#   '쪽수': 576,
#   '판매가': 35000},
#  {'제목': '반도체 특강 : 소자편',
#   '저자': '진종문',
#   '번역': '-',
#   '출간일': '2022-12-15',
#   '쪽수': 480,
#   '판매가': 28000},
#  {'제목': 'IT CookBook, 처음 만나는 자동제어공학(2판)',
#   '저자': '김성중',
#   '번역': '-',
#   '출간일': '2022-12-05',
#   '쪽수': 288,
#   '판매가': 23000},
#  {'제목': '누구나 R 데이터 분석',
#   '저자': '이윤환',
#   '번역': '-',
#   '출간일': '2022-10-20',
#   '쪽수': 436,
#   '판매가': 27000},
#  {'제목': 'STEM CookBook, 정수론 첫걸음',
#   '저자': 'Kuldeep Singh',
#   '번역': '한빛수학교재연구소 , 김도형(감수)',
#   '출간일': '2022-10-17',
#   '쪽수': 456,
#   '판매가': 33000},
#  {'제목': 'IT CookBook, C# 프로그래밍 for Beginner',
#   '저자': '우재남',
#   '번역': '-',
#   '출간일': '2022-10-06',
#   '쪽수': 632,
#   '판매가': 27000},
#  {'제목': 'R과 jamovi를 활용한 한번에 적용하는 의학보건통계',
#   '저자': '히든그레이스 데이터분석팀',
#   '번역': '-',
#   '출간일': '2022-09-30',
#   '쪽수': 448,
#   '판매가': 32000},
#  {'제목': '글로벌 시장환경과 국제경영',
#   '저자': '이장로 , 신만수 , 김창수',
#   '번역': '-',
#   '출간일': '2022-09-26',
#   '쪽수': 564,
#   '판매가': 40000},
#  {'제목': '미래 세상의 모빌리티',
#   '저자': '임덕신 , 임현준',
#   '번역': '-',
#   '출간일': '2022-09-15',
#   '쪽수': 280,
#   '판매가': 23000}]

# %% [markdown]
# ## DataFrame으로 변환

# %%
df = pd.DataFrame(lines)
df.head()
# Out:
#                                       제목                  저자  \
# 0      STEM CookBook, 전기 및 하이브리드 자동차(3판)        Iqbal Husain
# 1               IT CookBook, 컴퓨터 비전과 딥러닝                 오일석
# 2                      리더십 : 이론과 실제 (9판)  Peter G. Northouse
# 3                  IT CookBook, JAVA 마스터                 송미영
# 4  IT CookBook, 데이터 과학을 위한 파이썬 프로그래밍(2판)                 최성철
#
#                       번역         출간일   쪽수    판매가
# 0  임원식 , 김정윤 , 김기찬 , 강동우  2023-01-10  592  35000
# 1                      -  2023-01-05  664  39000
# 2                    김남현  2023-01-02  660  36000
# 3                      -  2023-01-01  732  30000
# 4                      -  2023-01-01  540  30000

# %% [markdown]
# # 3. 10페이지 정보 가져오기

# %%
lines = []
for page in tqdm(range(1,11)):
    url = base_url + sub_url + '?page=' + str(page)
    req = requests.get(url)
    soup = BeautifulSoup(req.text, 'html.parser')
    lis = soup.select('li.sub_book_list')
    
    for li in lis:
        href = li.find('a')['href']
        sub_req = requests.get(base_url + href)
        sub_soup = BeautifulSoup(sub_req.text, 'html.parser')

        title = sub_soup.select_one('.store_product_info_box > h3').text.strip()

        info_list = sub_soup.select('.info_list > li')
        info_dict = {}
        for li in info_list:
            key = li.find('strong').text.split(' ')[0]
            value = li.find('span').text.strip()
            info_dict[key] = value
            info_dict

        author = info_dict['저자']
        try:
            translator = info_dict['번역']
        except:
            translator = '-'
        date = info_dict['출간']
        pages = int(info_dict['페이지'].split(' ')[0].replace(',', ''))
        price = int(sub_soup.select_one('.pbr > strong').text.replace(',',''))
        lines.append({'제목' : title, '저자' : author, '번역' : translator, '출간일' : date, '쪽수' : pages, '판매가' : price})
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
df = pd.DataFrame(lines)
df
# Out:
#                                         제목                  저자  \
# 0        STEM CookBook, 전기 및 하이브리드 자동차(3판)        Iqbal Husain
# 1                 IT CookBook, 컴퓨터 비전과 딥러닝                 오일석
# 2                        리더십 : 이론과 실제 (9판)  Peter G. Northouse
# 3                    IT CookBook, JAVA 마스터                 송미영
# 4    IT CookBook, 데이터 과학을 위한 파이썬 프로그래밍(2판)                 최성철
# ..                                     ...                 ...
# 195                  NO BULLSHIT 선형대수학 가이드          Ivan Savov
# 196                  NO BULLSHIT 수학&물리 가이드          Ivan Savov
# 197                            정보교과교육론(2판)     이태욱 , 최현종 , 전용주
# 198      실무로 완성하는 PLC(멜섹Q) : 서보를 이용한 위치 제어                 정완보
# 199           College Physics, 5th Edition   Alan Giambattista
#
#                         번역         출간일    쪽수    판매가
# 0    임원식 , 김정윤 , 김기찬 , 강동우  2023-01-10   592  35000
# 1                        -  2023-01-05   664  39000
# 2                      김남현  2023-01-02   660  36000
# 3                        -  2023-01-01   732  30000
# 4                        -  2023-01-01   540  30000
# ..                     ...         ...   ...    ...
# 195        김대정 , 모현선 , 배준우  2020-01-06   628  28000
# 196                    권기영  2020-01-06   568  28000
# 197                      -  2020-01-06   464  27000
# 198                      -  2020-01-02   568  28000
# 199                      -  2020-01-01  1232  52000
#
# [200 rows x 6 columns]

# %%
df.to_csv('hanbitNewbook.csv', index=False)
