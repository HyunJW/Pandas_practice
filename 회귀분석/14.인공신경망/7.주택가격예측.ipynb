# %%
from keras.datasets import boston_housing
(X_train, y_trian), (X_test, y_test) = boston_housing.load_data()

# %%
print(X_train.shape, X_test.shape) # 학습용:검증용 404:102
print(X_train.shape[1]) # 독립변수의 개수
# Out:
# (404, 13) (102, 13)
# 13

# %%
y_trian[0:10] # 종속변수: 주택의 가격(천달러)
# Out:
# array([15.2, 42.3, 50. , 21.1, 17.7, 18.5, 11.3, 15.6, 15.6, 14.4])

# %%
import matplotlib.pyplot as plt
import pandas as pd
pd.DataFrame(X_train).boxplot()
plt.show()

# %%
#스케일링
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
pd.DataFrame(X_train_scaled).boxplot()
plt.show()

# %%
#64개의 노드를 가진 은닉층 2개의 신경망 모델
from keras import models, layers
def build_model():
    model = models.Sequential()
    # Dense(output, activation, input_shape)
    model.add(layers.Dense(64, activation='relu', 
                           input_shape=(X_train.shape[1], ))) # 독립변수의 개수
    model.add(layers.Dense(64, activation='relu'))
    # 출력층
    model.add(layers.Dense(1)) # activation='linear'
    model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
    return model

# %%
#모델 생성
model = build_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                896
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 5,121
# Trainable params: 5,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model,show_shapes=True)

# %%
#모델 학습
hist = model.fit(X_train_scaled, y_trian, epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 4ms/step - loss: 570.0848 - mae: 22.0568
# Epoch 2/100
# 7/7 [==============================] - 0s 9ms/step - loss: 528.2178 - mae: 21.0787
# Epoch 3/100
# 7/7 [==============================] - 0s 4ms/step - loss: 487.8974 - mae: 20.1207
# Epoch 4/100
# 7/7 [==============================] - 0s 4ms/step - loss: 443.0112 - mae: 19.0299
# Epoch 5/100
# 7/7 [==============================] - 0s 4ms/step - loss: 394.1432 - mae: 17.7749
# Epoch 6/100
# 7/7 [==============================] - 0s 4ms/step - loss: 342.1132 - mae: 16.3933
# Epoch 7/100
# 7/7 [==============================] - 0s 4ms/step - loss: 289.8792 - mae: 14.8848
# Epoch 8/100
# 7/7 [==============================] - 0s 4ms/step - loss: 239.8966 - mae: 13.3088
# Epoch 9/100
# 7/7 [==============================] - 0s 4ms/step - loss: 193.3818 - mae: 11.6967
# Epoch 10/100
# 7/7 [==============================] - 0s 6ms/step - loss: 153.8122 - mae: 10.2072
# Epoch 11/100
# 7/7 [==============================] - 0s 4ms/step - loss: 119.4908 - mae: 8.8402
# Epoch 12/100
# 7/7 [==============================] - 0s 4ms/step - loss: 94.2402 - mae: 7.7568
# Epoch 13/100
# 7/7 [==============================] - 0s 4ms/step - loss: 74.8709 - mae: 6.8654
# Epoch 14/100
# 7/7 [==============================] - 0s 4ms/step - loss: 60.9625 - mae: 6.1229
# Epoch 15/100
# 7/7 [==============================] - 0s 4ms/step - loss: 51.5797 - mae: 5.5075
# Epoch 16/100
# 7/7 [==============================] - 0s 5ms/step - loss: 45.0233 - mae: 5.1118
# Epoch 17/100
# 7/7 [==============================] - 0s 4ms/step - loss: 39.4571 - mae: 4.7254
# Epoch 18/100
# 7/7 [==============================] - 0s 4ms/step - loss: 35.0099 - mae: 4.3565
# Epoch 19/100
# 7/7 [==============================] - 0s 4ms/step - loss: 31.4604 - mae: 4.1008
# Epoch 20/100
# 7/7 [==============================] - 0s 4ms/step - loss: 28.6741 - mae: 3.9098
# Epoch 21/100
# 7/7 [==============================] - 0s 4ms/step - loss: 26.4785 - mae: 3.7108
# Epoch 22/100
# 7/7 [==============================] - 0s 4ms/step - loss: 24.8492 - mae: 3.6228
# Epoch 23/100
# 7/7 [==============================] - 0s 4ms/step - loss: 23.3965 - mae: 3.4305
# Epoch 24/100
# 7/7 [==============================] - 0s 4ms/step - loss: 22.0555 - mae: 3.3500
# Epoch 25/100
# 7/7 [==============================] - 0s 4ms/step - loss: 21.0645 - mae: 3.2792
# Epoch 26/100
# 7/7 [==============================] - 0s 4ms/step - loss: 19.9500 - mae: 3.1711
# Epoch 27/100
# 7/7 [==============================] - 0s 5ms/step - loss: 18.9391 - mae: 3.0725
# Epoch 28/100
# 7/7 [==============================] - 0s 4ms/step - loss: 18.2140 - mae: 3.0455
# Epoch 29/100
# 7/7 [==============================] - 0s 4ms/step - loss: 17.5233 - mae: 2.9644
# Epoch 30/100
# 7/7 [==============================] - 0s 4ms/step - loss: 16.7289 - mae: 2.8782
# Epoch 31/100
# 7/7 [==============================] - 0s 4ms/step - loss: 15.9174 - mae: 2.8268
# Epoch 32/100
# 7/7 [==============================] - 0s 4ms/step - loss: 15.6510 - mae: 2.7730
# Epoch 33/100
# 7/7 [==============================] - 0s 4ms/step - loss: 15.2472 - mae: 2.7504
# Epoch 34/100
# 7/7 [==============================] - 0s 4ms/step - loss: 14.6428 - mae: 2.6895
# Epoch 35/100
# 7/7 [==============================] - 0s 4ms/step - loss: 14.0514 - mae: 2.6326
# Epoch 36/100
# 7/7 [==============================] - 0s 4ms/step - loss: 13.8215 - mae: 2.6073
# Epoch 37/100
# 7/7 [==============================] - 0s 4ms/step - loss: 13.3975 - mae: 2.5759
# Epoch 38/100
# 7/7 [==============================] - 0s 4ms/step - loss: 12.9248 - mae: 2.5158
# Epoch 39/100
# 7/7 [==============================] - 0s 4ms/step - loss: 12.7961 - mae: 2.5095
# Epoch 40/100
# 7/7 [==============================] - 0s 4ms/step - loss: 12.5709 - mae: 2.4979
# Epoch 41/100
# 7/7 [==============================] - 0s 4ms/step - loss: 12.1281 - mae: 2.4150
# Epoch 42/100
# 7/7 [==============================] - 0s 4ms/step - loss: 11.8615 - mae: 2.4426
# Epoch 43/100
# 7/7 [==============================] - 0s 4ms/step - loss: 11.4843 - mae: 2.3851
# Epoch 44/100
# 7/7 [==============================] - 0s 4ms/step - loss: 11.4094 - mae: 2.3617
# Epoch 45/100
# 7/7 [==============================] - 0s 4ms/step - loss: 11.0807 - mae: 2.3902
# Epoch 46/100
# 7/7 [==============================] - 0s 4ms/step - loss: 11.0513 - mae: 2.3125
# Epoch 47/100
# 7/7 [==============================] - 0s 4ms/step - loss: 10.6324 - mae: 2.3179
# Epoch 48/100
# 7/7 [==============================] - 0s 4ms/step - loss: 10.5898 - mae: 2.2645
# Epoch 49/100
# 7/7 [==============================] - 0s 4ms/step - loss: 10.4178 - mae: 2.2602
# Epoch 50/100
# 7/7 [==============================] - 0s 4ms/step - loss: 10.3540 - mae: 2.2544
# Epoch 51/100
# 7/7 [==============================] - 0s 11ms/step - loss: 10.2653 - mae: 2.2570
# Epoch 52/100
# 7/7 [==============================] - 0s 4ms/step - loss: 10.0432 - mae: 2.2386
# Epoch 53/100
# 7/7 [==============================] - 0s 4ms/step - loss: 9.9129 - mae: 2.2098
# Epoch 54/100
# 7/7 [==============================] - 0s 4ms/step - loss: 9.9222 - mae: 2.2105
# Epoch 55/100
# 7/7 [==============================] - 0s 4ms/step - loss: 9.7695 - mae: 2.1997
# Epoch 56/100
# 7/7 [==============================] - 0s 4ms/step - loss: 9.8077 - mae: 2.1890
# Epoch 57/100
# 7/7 [==============================] - 0s 4ms/step - loss: 9.6824 - mae: 2.1968
# Epoch 58/100
# 7/7 [==============================] - 0s 4ms/step - loss: 9.3120 - mae: 2.1446
# Epoch 59/100
# 7/7 [==============================] - 0s 4ms/step - loss: 9.4271 - mae: 2.1700
# Epoch 60/100
# 7/7 [==============================] - 0s 4ms/step - loss: 9.3144 - mae: 2.1457
# Epoch 61/100
# 7/7 [==============================] - 0s 4ms/step - loss: 9.1452 - mae: 2.1372
# Epoch 62/100
# 7/7 [==============================] - 0s 4ms/step - loss: 9.3111 - mae: 2.1338
# Epoch 63/100
# 7/7 [==============================] - 0s 4ms/step - loss: 9.1945 - mae: 2.1174
# Epoch 64/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.8735 - mae: 2.0961
# Epoch 65/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.9022 - mae: 2.1031
# Epoch 66/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.9891 - mae: 2.1087
# Epoch 67/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.9841 - mae: 2.0937
# Epoch 68/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.8870 - mae: 2.1055
# Epoch 69/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.7369 - mae: 2.0617
# Epoch 70/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.5969 - mae: 2.0625
# Epoch 71/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.4883 - mae: 2.0488
# Epoch 72/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.5631 - mae: 2.0722
# Epoch 73/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.5482 - mae: 2.0464
# Epoch 74/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.3387 - mae: 2.0402
# Epoch 75/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.3357 - mae: 2.0603
# Epoch 76/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.4550 - mae: 2.0320
# Epoch 77/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.3179 - mae: 2.0538
# Epoch 78/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.3007 - mae: 2.0429
# Epoch 79/100
# 7/7 [==============================] - 0s 10ms/step - loss: 8.2896 - mae: 2.0915
# Epoch 80/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.0995 - mae: 2.0111
# Epoch 81/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.1347 - mae: 2.0280
# Epoch 82/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.0986 - mae: 2.0118
# Epoch 83/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.2543 - mae: 2.0518
# Epoch 84/100
# 7/7 [==============================] - 0s 4ms/step - loss: 7.9562 - mae: 1.9855
# Epoch 85/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.1645 - mae: 1.9996
# Epoch 86/100
# 7/7 [==============================] - 0s 5ms/step - loss: 7.8633 - mae: 1.9713
# Epoch 87/100
# 7/7 [==============================] - 0s 4ms/step - loss: 8.0334 - mae: 2.0161
# Epoch 88/100
# 7/7 [==============================] - 0s 4ms/step - loss: 7.8716 - mae: 1.9875
# Epoch 89/100
# 7/7 [==============================] - 0s 4ms/step - loss: 7.7712 - mae: 1.9617
# Epoch 90/100
# 7/7 [==============================] - 0s 4ms/step - loss: 7.8596 - mae: 2.0063
# Epoch 91/100
# 7/7 [==============================] - 0s 4ms/step - loss: 7.8169 - mae: 2.0006
# Epoch 92/100
# 7/7 [==============================] - 0s 4ms/step - loss: 7.8873 - mae: 1.9853
# Epoch 93/100
# 7/7 [==============================] - 0s 4ms/step - loss: 7.6054 - mae: 1.9540
# Epoch 94/100
# 7/7 [==============================] - 0s 4ms/step - loss: 7.7623 - mae: 1.9454
# Epoch 95/100
# 7/7 [==============================] - 0s 4ms/step - loss: 7.5414 - mae: 1.9457
# Epoch 96/100
# 7/7 [==============================] - 0s 4ms/step - loss: 7.7115 - mae: 1.9643
# Epoch 97/100
# 7/7 [==============================] - 0s 4ms/step - loss: 7.5064 - mae: 1.9515
# Epoch 98/100
# 7/7 [==============================] - 0s 4ms/step - loss: 7.5461 - mae: 1.9377
# Epoch 99/100
# 7/7 [==============================] - 0s 4ms/step - loss: 7.4637 - mae: 1.9151
# Epoch 100/100
# 7/7 [==============================] - 0s 4ms/step - loss: 7.4492 - mae: 1.9417

# %%
#검증용 데이터로 모델 평가
mse, mae = model.evaluate(X_test_scaled, y_test, verbose=1)
print(mse)
print(mae)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 22.5426 - mae: 2.9157
# 22.542612075805664
# 2.91572904586792

# %%
plt.plot(hist.history['mae'])
plt.ylabel('mae')
plt.xlabel('epoch')
plt.show()

# %%
#모델 저장
model.save('mymodel.h5')

# %%
#모델 불러오기
from keras.models import load_model
del model
model = load_model('mymodel.h5')
